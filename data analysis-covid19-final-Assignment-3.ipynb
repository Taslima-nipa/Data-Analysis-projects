# %%
#Import Vaccination Dataset of USA (Dataset-1)
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from unicodedata import normalize
import matplotlib.pylab as plt
#first download csv file from URL
#local path of csv file
USVaccURL="https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/country_data/United%20States.csv"
#read CSV file to pandas dataframe
dfUSVacc=pd.read_csv(USVaccURL)
#print dataframe
dfUSVacc
# Out:
#           location        date                                    vaccine  \
# 0    United States  2020-12-13                            Pfizer/BioNTech
# 1    United States  2020-12-14                            Pfizer/BioNTech
# 2    United States  2020-12-15                            Pfizer/BioNTech
# 3    United States  2020-12-16                            Pfizer/BioNTech
# 4    United States  2020-12-17                            Pfizer/BioNTech
# ..             ...         ...                                        ...
# 455  United States  2022-03-13  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 456  United States  2022-03-14  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 457  United States  2022-03-15  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 458  United States  2022-03-16  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 459  United States  2022-03-17  Johnson&Johnson, Moderna, Pfizer/BioNTech
#
#                                             source_url  total_vaccinations  \
# ...

# %%
#Columns of Dataset(Dataset-1)
dfUSVacc.columns
# Out:
# Index(['location', 'date', 'vaccine', 'source_url', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters'],
#       dtype='object')

# %%
#Printing data

dfUSVacc.head()
# Out:
#         location        date          vaccine  \
# 0  United States  2020-12-13  Pfizer/BioNTech
# 1  United States  2020-12-14  Pfizer/BioNTech
# 2  United States  2020-12-15  Pfizer/BioNTech
# 3  United States  2020-12-16  Pfizer/BioNTech
# 4  United States  2020-12-17  Pfizer/BioNTech
#
#                                           source_url  total_vaccinations  \
# 0  https://data.cdc.gov/Vaccinations/COVID-19-Vac...               29586
# 1  https://data.cdc.gov/Vaccinations/COVID-19-Vac...               34157
# 2  https://data.cdc.gov/Vaccinations/COVID-19-Vac...               83882
# 3  https://data.cdc.gov/Vaccinations/COVID-19-Vac...              243713
# 4  https://data.cdc.gov/Vaccinations/COVID-19-Vac...              516237
#
#    people_vaccinated  people_fully_vaccinated  total_boosters
# 0              24614                     5706               0
# 1              29025                     5825               0
# ...

# %%
#Printing data
dfUSVacc.tail()
# Out:
#           location        date                                    vaccine  \
# 455  United States  2022-03-13  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 456  United States  2022-03-14  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 457  United States  2022-03-15  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 458  United States  2022-03-16  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 459  United States  2022-03-17  Johnson&Johnson, Moderna, Pfizer/BioNTech
#
#                                             source_url  total_vaccinations  \
# 455  https://data.cdc.gov/Vaccinations/COVID-19-Vac...           557631308
# 456  https://data.cdc.gov/Vaccinations/COVID-19-Vac...           557807034
# 457  https://data.cdc.gov/Vaccinations/COVID-19-Vac...           557981956
# 458  https://data.cdc.gov/Vaccinations/COVID-19-Vac...           558104514
# 459  https://data.cdc.gov/Vaccinations/COVID-19-Vac...           558121106
#
#      people_vaccinated  people_fully_vaccinated  total_boosters
# ...

# %%
#to get information about column of dataset
dfUSVacc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460 entries, 0 to 459
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   location                 460 non-null    object
#  1   date                     460 non-null    object
#  2   vaccine                  460 non-null    object
#  3   source_url               460 non-null    object
#  4   total_vaccinations       460 non-null    int64
#  5   people_vaccinated        460 non-null    int64
#  6   people_fully_vaccinated  460 non-null    int64
#  7   total_boosters           460 non-null    int64
# dtypes: int64(4), object(4)
# memory usage: 28.9+ KB

# %%
#Data Cleaning
#Removed unecessary columns (vaccine,source_url)
dfUSVacc.drop(['location','vaccine','source_url','total_vaccinations','total_boosters','people_vaccinated'],axis=1,inplace=True)

# %%
#Columns after removed unecessary columns
dfUSVacc.columns
# Out:
# Index(['date', 'people_fully_vaccinated'], dtype='object')

# %%
#Columns information after removed unecessary columns
dfUSVacc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460 entries, 0 to 459
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     460 non-null    object
#  1   people_fully_vaccinated  460 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.3+ KB

# %%
#Printing Data after removing unnecessary columns
dfUSVacc
# Out:
#            date  people_fully_vaccinated
# 0    2020-12-13                     5706
# 1    2020-12-14                     5825
# 2    2020-12-15                     6085
# 3    2020-12-16                     6558
# 4    2020-12-17                     7299
# ..          ...                      ...
# 455  2022-03-13                216825493
# 456  2022-03-14                216871383
# 457  2022-03-15                216916501
# 458  2022-03-16                216947808
# 459  2022-03-17                216952347
#
# [460 rows x 2 columns]

# %%
#Graph to observe the rate of vaccination over time
plt.style.use('seaborn-whitegrid')
dfUSVacc.plot.line(x='date', y=['people_fully_vaccinated'])
plt.title('Increase of Vaccination with Time')
plt.show()

# %%
#Descriptive Analytics of Dataset-1
dfUSVacc.describe()
# Out:
#        people_fully_vaccinated
# count             4.600000e+02
# mean              1.395976e+08
# std               7.515857e+07
# min               5.706000e+03
# 25%               7.516113e+07
# 50%               1.698074e+08
# 75%               1.992251e+08
# max               2.169523e+08

# %%
#Graph - (Descriptive analytics)

arr1 = plt.vlines(dfUSVacc['people_fully_vaccinated'].mean(),
 ymin=0,
 ymax=0.4,
 linewidth=5.0,
 colors = "green"
 );
arr2 = plt.vlines(dfUSVacc['people_fully_vaccinated'].median(),
 ymin=0,
 ymax=0.4,
 linewidth=5.0,
 colors="red",
 );
arr3 = plt.vlines(
dfUSVacc['people_fully_vaccinated'].std(),
 ymin=0,
 ymax=0.4,
 linewidth=5.0,
 colors="yellow"
 );
plt.legend([arr1, arr2, arr3],['mean','median','std'],bbox_to_anchor=(1.0, 1),loc='upper left')
plt.title('Descriptive statistics of Dataset-1')
plt.show()

# %%
# Grouping vaccination data month wise
dfUSVacc['date'] = pd.to_datetime(dfUSVacc['date'])
dfUSVacc = dfUSVacc.sort_values(by='date')
dfUSVacc=dfUSVacc.groupby(pd.DatetimeIndex(dfUSVacc.date).to_period('M')).nth([-1])
dfUSVacc.set_index('date', inplace=True)
dfUSVacc.to_csv('dfUSVacc.csv')
dfUSVacc
# Out:
#             people_fully_vaccinated
# date
# 2020-12-31                    40720
# 2021-01-31                  7351091
# 2021-02-28                 29867214
# 2021-03-31                 64171965
# 2021-04-30                114146822
# 2021-05-31                145971530
# 2021-06-30                162484459
# 2021-07-31                169897435
# 2021-08-31                179658096
# 2021-09-30                189511379
# 2021-10-31                195765678
# 2021-11-30                200776827
# 2021-12-31                208435998
# 2022-01-31                213156809
# 2022-02-28                216129963
# 2022-03-17                216952347

# %%
#load covid19 death,confirmed and recovered data (Dataset-2)
urlCovid19='https://raw.githubusercontent.com/datasets/covid-19/master/data/countries-aggregated.csv'
dfUSCovid19Data=pd.read_csv(urlCovid19)
dfUSCovid19Data.rename(columns={'Date': 'date'}, inplace=True)
# Print Initial dataset of covid-19
dfUSCovid19Data
# Out:
#               date      Country  Confirmed  Recovered  Deaths
# 0       2020-01-22  Afghanistan          0          0       0
# 1       2020-01-23  Afghanistan          0          0       0
# 2       2020-01-24  Afghanistan          0          0       0
# 3       2020-01-25  Afghanistan          0          0       0
# 4       2020-01-26  Afghanistan          0          0       0
# ...            ...          ...        ...        ...     ...
# 155821  2022-03-14     Zimbabwe     242909          0    5416
# 155822  2022-03-15     Zimbabwe     242909          0    5416
# 155823  2022-03-16     Zimbabwe     243650          0    5418
# 155824  2022-03-17     Zimbabwe     243650          0    5418
# 155825  2022-03-18     Zimbabwe     244012          0    5420
#
# [155826 rows x 5 columns]

# %%
#Initial total columns of dfUSCovid19Data dataset
dfUSCovid19Data.columns
# Out:
# Index(['date', 'Country', 'Confirmed', 'Recovered', 'Deaths'], dtype='object')

# %%
#Initial columns info of dfUSCovid19Data dataset
dfUSCovid19Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155826 entries, 0 to 155825
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   date       155826 non-null  object
#  1   Country    155826 non-null  object
#  2   Confirmed  155826 non-null  int64
#  3   Recovered  155826 non-null  int64
#  4   Deaths     155826 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 5.9+ MB

# %%
#filtering data for considering only USA data
dfUSCovid19Data=dfUSCovid19Data.loc[(dfUSCovid19Data['Country'] == 'US') & (dfUSCovid19Data['date'] >= '2020-02-01') & (dfUSCovid19Data['date'] <= '2022-03-17')]

# %%
# Printing Covid-19 USA Data
dfUSCovid19Data.tail(10)
# Out:
#               date Country  Confirmed  Recovered  Deaths
# 144797  2022-03-08      US   79370693          0  962036
# 144798  2022-03-09      US   79408063          0  964012
# 144799  2022-03-10      US   79454543          0  965657
# 144800  2022-03-11      US   79504255          0  967121
# 144801  2022-03-12      US   79514718          0  967547
# 144802  2022-03-13      US   79525544          0  967715
# 144803  2022-03-14      US   79560288          0  965100
# 144804  2022-03-15      US   79585838          0  966381
# 144805  2022-03-16      US   79630853          0  968324
# 144806  2022-03-17      US   79683737          0  970009

# %%
#Information of colums and data after extraing USA data
dfUSCovid19Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 776 entries, 144031 to 144806
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       776 non-null    object
#  1   Country    776 non-null    object
#  2   Confirmed  776 non-null    int64
#  3   Recovered  776 non-null    int64
#  4   Deaths     776 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 36.4+ KB

# %%
#removed unnecessary columns, calculating death rate, and grouping
dfUSCovid19Data.drop(['Recovered'],axis=1,inplace=True)

#calculating death rate
dfUSCovid19Data['Deaths'] = (dfUSCovid19Data['Deaths']/dfUSCovid19Data['Confirmed'])*1


#Changing the format of date for the convenience of grouping data
dfUSCovid19Data['date'] = pd.to_datetime(dfUSCovid19Data['date'])

# Grouping month wise death rate of covid infected
dfUSCovid19Data=dfUSCovid19Data.groupby(pd.DatetimeIndex(dfUSCovid19Data.date).to_period('M')).nth([-1])
dfUSCovid19Data.set_index('date', inplace=True)
# Out:
# C:\Users\Taslima Akter\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\TASLIM~1\AppData\Local\Temp/ipykernel_12640/578029963.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfUSCovid19Data['Deaths'] = (dfUSCovid19Data['Deaths']/dfUSCovid19Data['Confirmed'])*1
# C:\Users\TASLIM~1\AppData\Local\Temp/ipykernel_12640/578029963.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfUSCovid19Data
# Out:
#            Country  Confirmed    Deaths
# date
# 2020-02-29      US         25  0.040000
# 2020-03-31      US     192079  0.027900
# 2020-04-30      US    1076478  0.061454
# 2020-05-31      US    1788187  0.060214
# 2020-06-30      US    2645046  0.048152
# 2020-07-31      US    4543581  0.033856
# 2020-08-31      US    6042745  0.030348
# 2020-09-30      US    7239776  0.028575
# 2020-10-31      US    9156199  0.025285
# 2020-11-30      US   13626608  0.019875
# 2020-12-31      US   20191923  0.017421
# 2021-01-31      US   26338845  0.017025
# 2021-02-28      US   28747921  0.017886
# 2021-03-31      US   30563154  0.018042
# 2021-04-30      US   32452189  0.017728
# 2021-05-31      US   33376665  0.017788
# 2021-06-30      US   33777015  0.017888
# 2021-07-31      US   35101042  0.017463
# 2021-08-31      US   39383351  0.016273
# 2021-09-30      US   43526291  0.016074
# 2021-10-31      US   46035834  0.016235
# 2021-11-30      US   48583376  0.016092
# ...

# %%
#before vaccination in the year 2020 , death rate
#dfUSCovid19Data.drop(['Confirmed'],axis=1,inplace=True)
print(dfUSCovid19Data)
dfUSCovid19Data.to_csv('dfUSCovid19Data.csv')
dfUSCovid19Data.rename(columns={'Confirmed': 'Covid_Postive'}, inplace=True)
# Out:
#            Country  Confirmed    Deaths
# date
# 2020-02-29      US         25  0.040000
# 2020-03-31      US     192079  0.027900
# 2020-04-30      US    1076478  0.061454
# 2020-05-31      US    1788187  0.060214
# 2020-06-30      US    2645046  0.048152
# 2020-07-31      US    4543581  0.033856
# 2020-08-31      US    6042745  0.030348
# 2020-09-30      US    7239776  0.028575
# 2020-10-31      US    9156199  0.025285
# 2020-11-30      US   13626608  0.019875
# 2020-12-31      US   20191923  0.017421
# 2021-01-31      US   26338845  0.017025
# 2021-02-28      US   28747921  0.017886
# 2021-03-31      US   30563154  0.018042
# 2021-04-30      US   32452189  0.017728
# 2021-05-31      US   33376665  0.017788
# 2021-06-30      US   33777015  0.017888
# 2021-07-31      US   35101042  0.017463
# 2021-08-31      US   39383351  0.016273
# 2021-09-30      US   43526291  0.016074
# 2021-10-31      US   46035834  0.016235
# 2021-11-30      US   48583376  0.016092
# ...

# %%
#Descriptive Analytics of Dataset-2
dfUSCovid19Data.describe()
# Out:
#        Covid_Postive     Deaths
# count   2.600000e+01  26.000000
# mean    2.896355e+07   0.024336
# std     2.461817e+07   0.013887
# min     2.500000e+01   0.011854
# 25%     6.342003e+06   0.016245
# 50%     2.965554e+07   0.017837
# 75%     4.249056e+07   0.028407
# max     7.968374e+07   0.061454

# %%
#Generating mean using mean() function
dfUSCovid19Data['Deaths'].mean()
# Out:
# 0.024335895028149788

# %%
#Generating median using median() function
dfUSCovid19Data['Deaths'].median()
# Out:
# 0.01783701447654136

# %%
#Generating std using std() function
dfUSCovid19Data['Deaths'].std()
# Out:
# 0.01388659889015038

# %%
# Descriptive Analytics of Dataset-2 (Graph)
arr1 = plt.vlines(dfUSCovid19Data['Deaths'].mean(), # Plot green line at mean
 ymin=0,
 ymax=0.4,
 linewidth=5.0,
 colors = "green"
 );
arr2 = plt.vlines(dfUSCovid19Data['Deaths'].median(), # Plot red line at median
 ymin=0,
 ymax=0.4,
 linewidth=5.0,
 colors="red",
 );
arr3 = plt.vlines(dfUSCovid19Data['Deaths'].std(), # Plot yellow line at std
 ymin=0,
 ymax=0.4,
 linewidth=5.0,
 colors="yellow"
 );
# place legend outside
#plt.legend(bbox_to_anchor=(1.0, 1), loc='upper left', title=('green - mean\nred - median\nyellow - standard deviation'))

plt.legend([arr1, arr2, arr3], ['mean','median','std'],bbox_to_anchor=(1.0, 1),loc='upper left')
plt.title('Descriptive statistics of Dataset-2')
plt.show()

# %%
#Bar chart to show the death percentage with time
plt.style.use('seaborn-whitegrid')
dfUSCovid19Data['Deaths'].plot.bar()
plt.title('Changes of death rate with date')
plt.show()

# %%
#merge covid19 data and vaccination data -- final comparison
#Left join because many covid-infected people died before vaccination.
#if we do right join these death before vaccination will lost from new dataset.
finaldfVaccCovid19=pd.merge(dfUSCovid19Data,dfUSVacc,on='date',how='left')
#In some rows where people are infected, deaths data are availabe but fully_vaccination data is Null,
#I fill that rows with with zero in vaccination column. 
finaldfVaccCovid19.fillna(0, inplace=True)
finaldfVaccCovid19.reset_index(inplace = True)
print(finaldfVaccCovid19)
# Out:
#          date Country  Covid_Postive    Deaths  people_fully_vaccinated
# 0  2020-02-29      US             25  0.040000                      0.0
# 1  2020-03-31      US         192079  0.027900                      0.0
# 2  2020-04-30      US        1076478  0.061454                      0.0
# 3  2020-05-31      US        1788187  0.060214                      0.0
# 4  2020-06-30      US        2645046  0.048152                      0.0
# 5  2020-07-31      US        4543581  0.033856                      0.0
# 6  2020-08-31      US        6042745  0.030348                      0.0
# 7  2020-09-30      US        7239776  0.028575                      0.0
# 8  2020-10-31      US        9156199  0.025285                      0.0
# 9  2020-11-30      US       13626608  0.019875                      0.0
# 10 2020-12-31      US       20191923  0.017421                  40720.0
# 11 2021-01-31      US       26338845  0.017025                7351091.0
# ...

# %%
# Changing column Name
finaldfVaccCovid19.rename(columns={'date': 'Date'}, inplace=True)
finaldfVaccCovid19.rename(columns={'people_fully_vaccinated': 'Fully_Vaccinated'}, inplace=True)
#printing the new generated tables
finaldfVaccCovid19
# Out:
#          Date Country  Covid_Postive    Deaths  Fully_Vaccinated
# 0  2020-02-29      US             25  0.040000               0.0
# 1  2020-03-31      US         192079  0.027900               0.0
# 2  2020-04-30      US        1076478  0.061454               0.0
# 3  2020-05-31      US        1788187  0.060214               0.0
# 4  2020-06-30      US        2645046  0.048152               0.0
# 5  2020-07-31      US        4543581  0.033856               0.0
# 6  2020-08-31      US        6042745  0.030348               0.0
# 7  2020-09-30      US        7239776  0.028575               0.0
# 8  2020-10-31      US        9156199  0.025285               0.0
# 9  2020-11-30      US       13626608  0.019875               0.0
# 10 2020-12-31      US       20191923  0.017421           40720.0
# 11 2021-01-31      US       26338845  0.017025         7351091.0
# 12 2021-02-28      US       28747921  0.017886        29867214.0
# ...

# %%
#Columns of new generated table
finaldfVaccCovid19.columns
# Out:
# Index(['Date', 'Country', 'Covid_Postive', 'Deaths', 'Fully_Vaccinated'], dtype='object')

# %%
#finding corelation between Death and Fully_Vaccinated variables
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

corrMatrix = finaldfVaccCovid19.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()
print('It has been seen that the variables "Death" and "Fully_Vaccinated" are negetively co-related.\nThat means, if vaccination is increased death is decreased.')
# Out:
# It has been seen that the variables "Death" and "Fully_Vaccinated" are negetively co-related.
# That means, if vaccination is increased death is decreased.

# %%
#finding corelation between Death and Fully_Vaccinated in another method
finaldfVaccCovid19[['Deaths','Fully_Vaccinated']].corr()
# Out:
#                    Deaths  Fully_Vaccinated
# Deaths            1.00000          -0.63876
# Fully_Vaccinated -0.63876           1.00000

# %%
#Priting new table for analytical convenience
finaldfVaccCovid19
# Out:
#          Date Country  Covid_Postive    Deaths  Fully_Vaccinated
# 0  2020-02-29      US             25  0.040000               0.0
# 1  2020-03-31      US         192079  0.027900               0.0
# 2  2020-04-30      US        1076478  0.061454               0.0
# 3  2020-05-31      US        1788187  0.060214               0.0
# 4  2020-06-30      US        2645046  0.048152               0.0
# 5  2020-07-31      US        4543581  0.033856               0.0
# 6  2020-08-31      US        6042745  0.030348               0.0
# 7  2020-09-30      US        7239776  0.028575               0.0
# 8  2020-10-31      US        9156199  0.025285               0.0
# 9  2020-11-30      US       13626608  0.019875               0.0
# 10 2020-12-31      US       20191923  0.017421           40720.0
# 11 2021-01-31      US       26338845  0.017025         7351091.0
# 12 2021-02-28      US       28747921  0.017886        29867214.0
# ...

# %%
#Deriving new variable to know how many of covid infected people have taken vaccine
sumoftotalinfected=finaldfVaccCovid19.Covid_Postive.sum()
sumoftotalVaccinated=finaldfVaccCovid19.Fully_Vaccinated.sum()
print('total covid positive: ', sumoftotalinfected)
print('total fully vaccinated: ', sumoftotalVaccinated)
percentage=(sumoftotalVaccinated/sumoftotalinfected)*100
print('percentage of vaccination among total covid infected people: ',percentage.round(3))
# Out:
# total covid positive:  753052419
# total fully vaccinated:  2314318333.0
# percentage of vaccination among total covid infected people:  307.325

# %%
finaldfVaccCovid19
# Out:
#          Date Country  Covid_Postive    Deaths  Fully_Vaccinated
# 0  2020-02-29      US             25  0.040000               0.0
# 1  2020-03-31      US         192079  0.027900               0.0
# 2  2020-04-30      US        1076478  0.061454               0.0
# 3  2020-05-31      US        1788187  0.060214               0.0
# 4  2020-06-30      US        2645046  0.048152               0.0
# 5  2020-07-31      US        4543581  0.033856               0.0
# 6  2020-08-31      US        6042745  0.030348               0.0
# 7  2020-09-30      US        7239776  0.028575               0.0
# 8  2020-10-31      US        9156199  0.025285               0.0
# 9  2020-11-30      US       13626608  0.019875               0.0
# 10 2020-12-31      US       20191923  0.017421           40720.0
# 11 2021-01-31      US       26338845  0.017025         7351091.0
# 12 2021-02-28      US       28747921  0.017886        29867214.0
# ...

# %%
#Deriving new feature to easily understand which people are died before and after vaccination
finaldfVaccCovid19['Vaccination_Status']=np.where((finaldfVaccCovid19.Deaths > 0.0) & (finaldfVaccCovid19.Fully_Vaccinated > 0.0),'Fully Vaccinated','Not vaccinated')

# %%
finaldfVaccCovid19['Vaccination_Status']
# Out:
# 0       Not vaccinated
# 1       Not vaccinated
# 2       Not vaccinated
# 3       Not vaccinated
# 4       Not vaccinated
# 5       Not vaccinated
# 6       Not vaccinated
# 7       Not vaccinated
# 8       Not vaccinated
# 9       Not vaccinated
# 10    Fully Vaccinated
# 11    Fully Vaccinated
# 12    Fully Vaccinated
# 13    Fully Vaccinated
# 14    Fully Vaccinated
# 15    Fully Vaccinated
# 16    Fully Vaccinated
# 17    Fully Vaccinated
# 18    Fully Vaccinated
# 19    Fully Vaccinated
# 20    Fully Vaccinated
# 21    Fully Vaccinated
# 22    Fully Vaccinated
# 23    Fully Vaccinated
# 24    Fully Vaccinated
# 25    Fully Vaccinated
# Name: Vaccination_Status, dtype: object

# %%
finaldfVaccCovid19
# Out:
#          Date Country  Covid_Postive    Deaths  Fully_Vaccinated  \
# 0  2020-02-29      US             25  0.040000               0.0
# 1  2020-03-31      US         192079  0.027900               0.0
# 2  2020-04-30      US        1076478  0.061454               0.0
# 3  2020-05-31      US        1788187  0.060214               0.0
# 4  2020-06-30      US        2645046  0.048152               0.0
# 5  2020-07-31      US        4543581  0.033856               0.0
# 6  2020-08-31      US        6042745  0.030348               0.0
# 7  2020-09-30      US        7239776  0.028575               0.0
# 8  2020-10-31      US        9156199  0.025285               0.0
# 9  2020-11-30      US       13626608  0.019875               0.0
# 10 2020-12-31      US       20191923  0.017421           40720.0
# 11 2021-01-31      US       26338845  0.017025         7351091.0
# 12 2021-02-28      US       28747921  0.017886        29867214.0
# ...

# %%
#Graph to show death percentage before and after vaccination
plt.style.use('seaborn-whitegrid')
finaldfVaccCovid19.plot.line(x='Fully_Vaccinated', y=['Deaths'])
plt.title('Changes of Death Rates with Vaccination in USA')
plt.show()

# %%
#Copy to CSV File
finaldfVaccCovid19.to_csv('finaldfVaccCovid19.csv')

# %%
#Creating Report in Pandas
from pandas_profiling import ProfileReport

prof = ProfileReport(finaldfVaccCovid19)
prof.to_file(output_file='finaldfVaccCovid19_merge_col_prof.html')
prof
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-03-20 02:11:19.715397&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
