# %%
#Codes Provided in the Class for Lab-4
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize

# %%
import os, ssl
if (not os.environ.get('PYTHONHTTPSVERIFY', '') and getattr(ssl, '_create_unverified_context', None)):
    ssl._create_default_https_context = ssl._create_unverified_context

# %%
table_MN = pd.read_html('https://en.wikipedia.org/wiki/Minnesota')
table_MN
# Out:
# [                                            Minnesota  \
#  0                                               State
#  1                                  State of Minnesota
#  2   .mw-parser-output .ib-settlement-cols{text-ali...
#  3   Nickname(s): Land of 10,000 Lakes;North Star S...
#  4   Motto(s): L'Étoile du Nord (French: The Star o...
#  5                           Anthem: "Hail! Minnesota"
#  6   Map of the United States with Minnesota highli...
#  7                                             Country
#  8                                    Before statehood
#  9                               Admitted to the Union
#  10                                            Capital
#  11                                       Largest city
#  12                      Largest metro and urban areas
#  13                                         Government
#  14                                         • Governor
#  15                              • Lieutenant Governor
#  16                                        Legislature
#  17                                      • Upper house
#  18                                      • Lower house
#  19                                          Judiciary
#  20                                      U.S. senators
#  21                              U.S. House delegation
#  22                                               Area
#  23                                            • Total
#  24                                             • Land
#  25                                            • Water
#  26                                             • Rank
#  27                                         Dimensions
#  28                                           • Length
#  29                                            • Width
#  30                                          Elevation
#  31           Highest elevation (Eagle Mountain[1][2])
#  32          Lowest elevation (Lake Superior[1][2][3])
#  33                                  Population (2021)
#  34                                            • Total
#  35                                             • Rank
#  36                                          • Density
#  37                                             • Rank
#  38                          • Median household income
#  39                                      • Income rank
#  40                                         Demonym(s)
#  41                                           Language
#  42                                • Official language
#  43                                  • Spoken language
#  44                                          Time zone
#  45                                     • Summer (DST)
#  46                                  USPS abbreviation
#  47                                      ISO 3166 code
#  48                           Traditional abbreviation
#  49                                           Latitude
#  50                                          Longitude
#  51                                            Website
#
#                                            Minnesota.1
#  0                                               State
#  1                                  State of Minnesota
#  2   .mw-parser-output .ib-settlement-cols{text-ali...
#  3   Nickname(s): Land of 10,000 Lakes;North Star S...
#  4   Motto(s): L'Étoile du Nord (French: The Star o...
#  5                           Anthem: "Hail! Minnesota"
#  6   Map of the United States with Minnesota highli...
#  7                                       United States
#  8                                 Minnesota Territory
#  9              May 11, 1858 (32nd State in the Union)
#  10                                         Saint Paul
#  11                                        Minneapolis
#  12                             Minneapolis–Saint Paul
#  13                                         Government
#  14                                     Tim Walz (DFL)
#  15                               Peggy Flanagan (DFL)
#  16                              Minnesota Legislature
#  17                                             Senate
#  18                           House of Representatives
#  19                            Minnesota Supreme Court
#  20                Amy Klobuchar (DFL)Tina Smith (DFL)
#  21           4 Democrats3 Republicans1 vacancy (list)
#  22                                               Area
#  23                      86,935.83 sq mi (225,163 km2)
#  24                      79,626.74 sq mi (206,232 km2)
#  25                  7,309.09 sq mi (18,930 km2) 8.40%
#  26                                               12th
#  27                                         Dimensions
#  28                              about 400 mi (640 km)
#  29                            200–350 mi (320–560 km)
#  30                                   1,200 ft (370 m)
#  31                                   2,301 ft (701 m)
#  32                                     602 ft (183 m)
#  33                                  Population (2021)
#  34                                       5,707,390[4]
#  35                                               22nd
#  36                              68.9/sq mi (26.6/km2)
#  37                               30th (2015 estimate)
#  38                                         $74,593[5]
#  39                                               13th
#  40                                         Minnesotan
#  41                                           Language
#  42                                               None
#  43              English 88.9% Spanish Somali Hmong[6]
#  44                                UTC−06:00 (Central)
#  45                                    UTC−05:00 (CDT)
#  46                                                 MN
#  47                                              US-MN
#  48                                              Minn.
#  49                             43° 30′ N to 49° 23′ N
#  50                             89° 29′ W to 97° 14′ W
#  51                                             mn.gov  ,
#                   Minnesota state symbols  \
#                           Living insignia
#  0                                   Bird
#  1                              Butterfly
#  2                                   Fish
#  3                                 Flower
#  4                               Mushroom
#  5                                   Tree
#  6                     Inanimate insignia
#  7                               Beverage
#  8                                   Food
#  9                               Gemstone
#  10                                 Other
#  11  Lists of United States state symbols
#
#
#                                      Living insignia.1
#  0                                         Common loon
#  1                                             Monarch
#  2                                             Walleye
#  3                       Pink-and-white lady's slipper
#  4                  Common morel (Morchella esculenta)
#  5                                      Norway pine[7]
#  6                                  Inanimate insignia
#  7                                                Milk
#  8   Fruit: Honeycrisp appleMuffin: BlueberryMushro...
#  9                                 Lake Superior agate
#  10                                  Photograph: Grace
#  11               Lists of United States state symbols  ,
#                Location July (°F) July (°C) January (°F) January (°C)
#  0          Minneapolis     83/64     28/18         23/7       −4/−13
#  1           Saint Paul     83/63     28/17         23/6       −5/−14
#  2            Rochester     82/63     28/17         23/3       −5/−16
#  3               Duluth     76/55     24/13         19/1       −7/−17
#  4            St. Cloud     81/58     27/14        18/−1       −7/−18
#  5              Mankato     86/62     30/16         23/3       −5/−16
#  6  International Falls     77/52     25/11        15/−6       −9/−21,
#                      Historical population  \
#                                     Census
#  0                                    1850
#  1                                    1860
#  2                                    1870
#  3                                    1880
#  4                                    1890
#  5                                    1900
#  6                                    1910
#  7                                    1920
#  8                                    1930
#  9                                    1940
#  10                                   1950
#  11                                   1960
#  12                                   1970
#  13                                   1980
#  14                                   1990
#  15                                   2000
#  16                                   2010
#  17                                   2020
#  18                            2021 (est.)
#  19  Source: 1910–2020[75]2021 Estimate[4]
#
#                                             \
#                                       Pop.
#  0                                    6077
#  1                                  172023
#  2                                  439706
#  3                                  780773
#  4                                 1310283
#  5                                 1751394
#  6                                 2075708
#  7                                 2387125
#  8                                 2563953
#  9                                 2792300
#  10                                2982483
#  11                                3413864
#  12                                3804971
#  13                                4075970
#  14                                4375099
#  15                                4919479
#  16                                5303925
#  17                                5706494
#  18                                5707390
#  19  Source: 1910–2020[75]2021 Estimate[4]
#
#                                             \
#                         Unnamed: 2_level_1
#  0                                     NaN
#  1                                     NaN
#  2                                     NaN
#  3                                     NaN
#  4                                     NaN
#  5                                     NaN
#  6                                     NaN
#  7                                     NaN
#  8                                     NaN
#  9                                     NaN
#  10                                    NaN
#  11                                    NaN
#  12                                    NaN
#  13                                    NaN
#  14                                    NaN
#  15                                    NaN
#  16                                    NaN
#  17                                    NaN
#  18                                    NaN
#  19  Source: 1910–2020[75]2021 Estimate[4]
#
#
#                                         %±
#  0                                       —
#  1                                2,730.7%
#  2                                  155.6%
#  3                                   77.6%
#  4                                   67.8%
#  5                                   33.7%
#  6                                   18.5%
#  7                                   15.0%
#  8                                    7.4%
#  9                                    8.9%
#  10                                   6.8%
#  11                                  14.5%
#  12                                  11.5%
#  13                                   7.1%
#  14                                   7.3%
#  15                                  12.4%
#  16                                   7.8%
#  17                                   7.6%
#  18                                   7.6%
#  19  Source: 1910–2020[75]2021 Estimate[4]  ,
#              Race and Ethnicity[79]  Alone  Alone.1  Total  Total.1
#  0             White (non-Hispanic)  76.3%      NaN  80.2%      NaN
#  1  African American (non-Hispanic)   6.9%      NaN   8.2%      NaN
#  2            Hispanic or Latino[a]      —      NaN   6.1%      NaN
#  3                            Asian   5.2%      NaN   6.2%      NaN
#  4                  Native American   1.0%      NaN   2.3%      NaN
#  5                 Pacific Islander  0.05%      NaN   0.1%      NaN
#  6                            Other   0.4%      NaN   1.3%      NaN,
#                        Affiliation  % of population  % of population.1
#  0                       Christian               74                NaN
#  1                      Protestant               50                NaN
#  2                        Lutheran               26                NaN
#  3                       Methodist                3                NaN
#  4                     Pentecostal                3                NaN
#  5   Historically Black Protestant                2                NaN
#  6                Other Protestant               16                NaN
#  7                  Roman Catholic               22                NaN
#  8                          Mormon                1                NaN
#  9                 Other Christian                1                NaN
#  10  Other religion or association                5                NaN
#  11                        Judaism                1                NaN
#  12                          Islam                1                NaN
#  13          Other and unspecified                3                NaN
#  14                   Unaffiliated               20                NaN
#  15          Nothing in particular               13                NaN
#  16                       Agnostic                4                NaN
#  17                        Atheist                3                NaN,
#      Year     Office    GOP    DFL Others
#  0   2020  President  45.3%  52.4%   2.3%
#  1   2020    Senator  43.5%  48.8%   7.7%
#  2   2018   Governor  42.4%  53.9%   3.7%
#  3   2018    Senator  36.2%  60.3%   3.4%
#  4   2018    Senator  42.4%  53.0%   4.6%
#  5   2016  President  44.9%  46.4%   8.6%
#  6   2014   Governor  44.5%  50.1%   5.4%
#  7   2014    Senator  42.9%  53.2%   3.9%
#  8   2012  President  45.1%  52.8%   2.1%
#  9   2012    Senator  30.6%  65.3%   4.1%
#  10  2010   Governor  43.2%  43.7%  13.1%
#  11  2008  President  43.8%  54.1%   2.1%
#  12  2008    Senator  42.0%  42.0%  16.0%
#  13  2006   Governor  46.7%  45.7%   7.6%
#  14  2006    Senator  37.9%  58.1%   4.0%
#  15  2004  President  47.6%  51.1%   1.3%
#  16  2002   Governor  44.4%  33.5%  22.1%
#  17  2002    Senator  49.5%  47.3%   1.0%
#  18  2000  President  45.5%  47.9%   6.6%
#  19  2000    Senator  43.3%  48.8%   7.9%
#  20  1998   Governor  34.3%  28.1%  37.6%
#  21  1996  President  35.0%  51.1%  13.9%
#  22  1996    Senator  41.3%  50.3%   8.4%
#  23  1994   Governor  63.3%  34.1%   2.6%
#  24  1994    Senator  49.1%  44.1%   6.8%
#  25  1992  President  31.9%  43.5%  24.6%,
#                         0                                                  1  \
#  0  Preceded byCalifornia  List of U.S. states by date of statehood Admit...
#
#                      2
#  0  Succeeded byOregon  ,
#         Topics related to MinnesotaLand of 10,000 Lakes  \
#  0    .mw-parser-output .navbar{display:inline;font-...
#  1    .mw-parser-output .navbar{display:inline;font-...
#  2                                 Saint Paul (capital)
#  3                                               Topics
#  4                                              Society
#  ..                                                 ...
#  97                                    Federal district
#  98                                       Insular areas
#  99                                    Outlying islands
#  100                                Indian reservations
#  101                                             Others
#
#       Topics related to MinnesotaLand of 10,000 Lakes.1  \
#  0    .mw-parser-output .navbar{display:inline;font-...
#  1    .mw-parser-output .navbar{display:inline;font-...
#  2                                 Saint Paul (capital)
#  3    Index Outline Biking/Cycling Cities Climate (C...
#  4    Culture Crime Demographics Economy Education L...
#  ..                                                 ...
#  97                                    Washington, D.C.
#  98   American Samoa Guam Northern Mariana Islands P...
#  99   Baker Island Howland Island Jarvis Island John...
#  100                        List of Indian reservations
#  101                                    Federal enclave
#
#                                              Unnamed: 2
#  0                                                  NaN
#  1    .mw-parser-output .navbar{display:inline;font-...
#  2                                 Saint Paul (capital)
#  3                                    Seal of Minnesota
#  4                                    Seal of Minnesota
#  ..                                                 ...
#  97                                                 NaN
#  98                                                 NaN
#  99                                                 NaN
#  100                                                NaN
#  101                                                NaN
#
#  [102 rows x 3 columns],
#    .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vte State of Minnesota  \
#  0                               Saint Paul (capital)
#  1                                             Topics
#  2                                            Society
#  3                                            Regions
#  4                     Largest citiespop. over 25,000
#  5                                           Counties
#  6                                        Attractions
#  7                                          Festivals
#  8                                              Other
#  9                                   Minnesota portal
#
#    .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vte State of Minnesota.1  \
#  0                               Saint Paul (capital)
#  1  Index Outline Biking/Cycling Cities Climate (C...
#  2  Culture Crime Demographics Economy Education L...
#  3  Arrowhead Boundary Waters Buffalo Ridge Centra...
#  4  Andover Apple Valley Blaine Bloomington Brookl...
#  5  Aitkin Anoka Becker Beltrami Benton Big Stone ...
#  6         Festivals State Fair Other Mall of America
#  7                                         State Fair
#  8                                    Mall of America
#  9                                   Minnesota portal
#
#    .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vte State of Minnesota.2
#  0                               Saint Paul (capital)
#  1                                  Seal of Minnesota
#  2                                  Seal of Minnesota
#  3                                  Seal of Minnesota
#  4                                  Seal of Minnesota
#  5                                  Seal of Minnesota
#  6                                  Seal of Minnesota
#  7                                                NaN
#  8                                                NaN
#  9                                   Minnesota portal                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ,
#             0                1
#  0  Festivals       State Fair
#  1      Other  Mall of America,
#    vteMayors of cities with populations exceeding 100,000 in Minnesota  \
#  0  .mw-parser-output .div-col{margin-top:0.3em;co...
#
#    vteMayors of cities with populations exceeding 100,000 in Minnesota.1  \
#  0  .mw-parser-output .div-col{margin-top:0.3em;co...
#
#     vteMayors of cities with populations exceeding 100,000 in Minnesota.2
#  0                                                NaN                      ,
#                vteProtected areas of Minnesota  \
#  0                                    National
#  1                                       Parks
#  2                                   Monuments
#  3                                      Rivers
#  4                               Scenic Trails
#  5                             WildlifeRefuges
#  6                  WetlandManagementDistricts
#  7                                     Forests
#  8                            NaturalLandmarks
#  9                                  Wilderness
#  10                                      State
#  11                                      Parks
#  12                            RecreationAreas
#  13                                   Waysides
#  14                                    Forests
#  15                Scientific andNatural Areas
#  16                                      Local
#  17                                      Parks
#  18                                      Other
#  19                 MinnesotaHistoricalSociety
#  20                              Naturecenters
#  21                                     Hiking
#  22  Minnesota Department of Natural Resources
#
#                      vteProtected areas of Minnesota.1
#  0   Parks Voyageurs Monuments Grand Portage Pipest...
#  1                                           Voyageurs
#  2                             Grand Portage Pipestone
#  3   Mississippi National River and Recreation Area...
#  4                                 North Country Trail
#  5   Agassiz Big Stone Crane Meadows Glacial Ridge ...
#  6   Big Stone Detroit Lakes Fergus Falls Litchfiel...
#  7                                   Chippewa Superior
#  8   Ancient River Warren Channel Cedar Creek Ecosy...
#  9          Agassiz Boundary Waters Canoe Area Tamarac
#  10  Parks Afton Banning Bear Head Lake Beaver Cree...
#  11  Afton Banning Bear Head Lake Beaver Creek Vall...
#  12  Big Bog Cuyuna Country Garden Island Greenleaf...
#  13  Caribou Falls Devils Track Falls Flood Bay Ins...
#  14  Badoura Battleground Bear Island Beltrami Isla...
#  15               List of scientific and natural areas
#  16  Parks County and regional parks Three Rivers P...
#  17  County and regional parks Three Rivers Park Di...
#  18  MinnesotaHistoricalSociety Alexander Ramsey Ho...
#  19  Alexander Ramsey House Birch Coulee Battlefiel...
#  20                             List of nature centers
#  21                              List of hiking trails
#  22          Minnesota Department of Natural Resources  ,
#                              0  \
#  0                       Parks
#  1                   Monuments
#  2                      Rivers
#  3               Scenic Trails
#  4             WildlifeRefuges
#  5  WetlandManagementDistricts
#  6                     Forests
#  7            NaturalLandmarks
#  8                  Wilderness
#
#                                                     1
#  0                                          Voyageurs
#  1                            Grand Portage Pipestone
#  2  Mississippi National River and Recreation Area...
#  3                                North Country Trail
#  4  Agassiz Big Stone Crane Meadows Glacial Ridge ...
#  5  Big Stone Detroit Lakes Fergus Falls Litchfiel...
#  6                                  Chippewa Superior
#  7  Ancient River Warren Channel Cedar Creek Ecosy...
#  8         Agassiz Boundary Waters Canoe Area Tamarac  ,
#                               0  \
#  0                        Parks
#  1              RecreationAreas
#  2                     Waysides
#  3                      Forests
#  4  Scientific andNatural Areas
#
#                                                     1
#  0  Afton Banning Bear Head Lake Beaver Creek Vall...
#  1  Big Bog Cuyuna Country Garden Island Greenleaf...
#  2  Caribou Falls Devils Track Falls Flood Bay Ins...
#  3  Badoura Battleground Bear Island Beltrami Isla...
#  4               List of scientific and natural areas  ,
#         0                                                  1
#  0  Parks  County and regional parks Three Rivers Park Di...,
#                              0  \
#  0  MinnesotaHistoricalSociety
#  1               Naturecenters
#  2                      Hiking
#
#                                                     1
#  0  Alexander Ramsey House Birch Coulee Battlefiel...
#  1                             List of nature centers
#  2                              List of hiking trails  ,
#    vteMidwestern United States  \
#  0                      Topics
#  1                      States
#  2                Major cities
#  3              State capitals
#
#                         vteMidwestern United States.1
#  0  Culture Geography Economy Government and polit...
#  1  Ohio Indiana Michigan Illinois Missouri Iowa W...
#  2  Chicago Detroit Minneapolis St. Paul St. Louis...
#  3  Columbus Indianapolis Lansing Springfield Jeff...  ,
#     vte New France (1534–1763)  \
#  0                     History
#  1                Subdivisions
#  2          Towns and villages
#  3                       Forts
#  4                  Government
#  5                         Law
#  6                     Economy
#  7                     Society
#  8                    Religion
#  9               War and peace
#  10          Category  Commons
#
#                           vte New France (1534–1763).1  \
#  0   French colonization of the Americas French col...
#  1   Acadia (1604–1713) Canada (1608–1763) Pays d'e...
#  2   Acadia (Port Royal) Canada Quebec Trois-Rivièr...
#  3   Fort Rouillé Fort Michilimackinac Fort de Buad...
#  4   Canada Governor General Intendant Sovereign Co...
#  5   Custom of Paris in New France Criminal justice...
#  6   Seigneurial system Fur trade Coureur des bois ...
#  7   Population 1666 census Habitants King's Daught...
#  8   Jesuit missions Récollets Grey Nuns Ursulines ...
#  9   Military of New France Intercolonial Wars Fren...
#  10                                  Category  Commons
#
#                           vte New France (1534–1763).2
#  0   The lesser coat of arms of France as used by t...
#  1   The lesser coat of arms of France as used by t...
#  2   The lesser coat of arms of France as used by t...
#  3   The lesser coat of arms of France as used by t...
#  4   The lesser coat of arms of France as used by t...
#  5   The lesser coat of arms of France as used by t...
#  6   The lesser coat of arms of France as used by t...
#  7   The lesser coat of arms of France as used by t...
#  8   The lesser coat of arms of France as used by t...
#  9   The lesser coat of arms of France as used by t...
#  10                                  Category  Commons  ,
#                              vte New Spain (1521–1821)  \
#  0                                           Conflicts
#  1   Spanish conquest of the Aztec Empire → Spanish...
#  2   Conflicts with indigenouspeoples during coloni...
#  3                 Centralgovernmentand administration
#  4                                      Habsburg Spain
#  5                                       Bourbon Spain
#  6                               Viceroys of New Spain
#  7                                          Audiencias
#  8                                  Captancies General
#  9                                          Intendancy
#  10                                           Politics
#  11                                           Treaties
#  12            Notablecities,provinces,and territories
#  13                                             Cities
#  14                           Provinces andterritories
#  15                                        Other areas
#  16             Explorers,adventurers andconquistadors
#  17                             Pre-New Spainexplorers
#  18                         Explorers andconquistadors
#  19                        Catholic Churchin New Spain
#  20                    Spanish missionsin the Americas
#  21               Friars, fathers,priests, and bishops
#  22                                       Other events
#  23                                 Societyand culture
#  24                                  Indigenouspeoples
#  25                                       Mesoamerican
#  26                                          Caribbean
#  27                                         California
#  28                                       Southwestern
#  29                             North-Northwest Mexico
#  30               Florida and otherSoutheastern tribes
#  31                                          Filipinos
#  32                                             Others
#  33                                       Architecture
#  34                                  Trade and economy
#  35                                 People and classes
#  36                                             People
#  37                                           Category
#
#                            vte New Spain (1521–1821).1
#  0   Spanish conquest of the Aztec Empire → Spanish...
#  1   Spanish conquest of the Aztec Empire → Spanish...
#  2   Mixtón War → Yaqui Wars → Chichimeca War → Phi...
#  3   Habsburg Spain Charles I Joanna of Castile Phi...
#  4   Charles I Joanna of Castile Philip II Philp II...
#  5   Philip V (also reigned after Louis I) Louis I ...
#  6                       List of viceroys of New Spain
#  7   Guadalajara Captaincy General of Guatemala Man...
#  8   Cuba Guatemala Philippines Puerto Rico Santo D...
#  9   Havana New Orleans State of Mexico Chiapas Com...
#  10  Viceroy Gobernaciones Adelantado Captain gener...
#  11  Treaty of Tordesillas Treaty of Zaragoza Peace...
#  12  Cities Mexico City Veracruz Xalapa Puebla Tolu...
#  13  Mexico City Veracruz Xalapa Puebla Toluca Cuer...
#  14  La Florida (Florida) Las Californias Alta Cali...
#  15                                    Spanish Formosa
#  16  Pre-New Spainexplorers Christopher Columbus Fe...
#  17  Christopher Columbus Ferdinand Magellan Juan S...
#  18  Hernán Cortés Juan Ponce de León Nuño de Guzmá...
#  19  Spanish missionsin the Americas Spanish missio...
#  20  Spanish missions in Arizona Spanish missions i...
#  21  Pedro de Gante Gerónimo de Aguilar Toribio de ...
#  22  Our Lady of Guadalupe Suppression of the Jesui...
#  23  IndigenouspeoplesMesoamerican Aztecs Maya Huas...
#  24  Mesoamerican Aztecs Maya Huastec Mixtec P'urhé...
#  25  Aztecs Maya Huastec Mixtec P'urhépecha Totonac...
#  26                        Arawak Ciboney Guanahatabey
#  27  Mission Indians Cahuilla Chumash Cupeño Juaneñ...
#  28  Apache Coahuiltecan Cocopah Comanche Hopi Hual...
#  29    Acaxee Chichimeca Cochimí Kiliwa Opata Tepehuán
#  30  Indigenous people during De Soto's travels Apa...
#  31  Negrito Igorot Mangyan Peoples of Palawan Ati ...
#  32       Taiwanese indigenous peoples Chamorro people
#  33  Spanish Colonial style by country Colonial Bar...
#  34  Real Columbian exchange Manila galleon Triangu...
#  35  Casta Peninsulares Criollo Indios Mestizo Cast...
#  36  Juan Bautista de Anza Juan Rodríguez Cabrillo ...
#  37                                           Category  ,
#                                                     0  \
#  0  Spanish conquest of the Aztec Empire → Spanish...
#  1  Conflicts with indigenouspeoples during coloni...
#
#                                                     1
#  0  Spanish conquest of the Aztec Empire → Spanish...
#  1  Mixtón War → Yaqui Wars → Chichimeca War → Phi...  ,
#                         0                                                  1
#  0         Habsburg Spain  Charles I Joanna of Castile Philip II Philp II...
#  1          Bourbon Spain  Philip V (also reigned after Louis I) Louis I ...
#  2  Viceroys of New Spain                      List of viceroys of New Spain
#  3             Audiencias  Guadalajara Captaincy General of Guatemala Man...
#  4     Captancies General  Cuba Guatemala Philippines Puerto Rico Santo D...
#  5             Intendancy  Havana New Orleans State of Mexico Chiapas Com...
#  6               Politics  Viceroy Gobernaciones Adelantado Captain gener...
#  7               Treaties  Treaty of Tordesillas Treaty of Zaragoza Peace...,
#                            0                                                  1
#  0                    Cities  Mexico City Veracruz Xalapa Puebla Toluca Cuer...
#  1  Provinces andterritories  La Florida (Florida) Las Californias Alta Cali...
#  2               Other areas                                    Spanish Formosa,
#                              0  \
#  0      Pre-New Spainexplorers
#  1  Explorers andconquistadors
#
#                                                     1
#  0  Christopher Columbus Ferdinand Magellan Juan S...
#  1  Hernán Cortés Juan Ponce de León Nuño de Guzmá...  ,
#                                        0  \
#  0       Spanish missionsin the Americas
#  1  Friars, fathers,priests, and bishops
#  2                          Other events
#
#                                                     1
#  0  Spanish missions in Arizona Spanish missions i...
#  1  Pedro de Gante Gerónimo de Aguilar Toribio de ...
#  2  Our Lady of Guadalupe Suppression of the Jesui...  ,
#                                         0  \
#  0                      Indigenouspeoples
#  1                           Mesoamerican
#  2                              Caribbean
#  3                             California
#  4                           Southwestern
#  5                 North-Northwest Mexico
#  6   Florida and otherSoutheastern tribes
#  7                              Filipinos
#  8                                 Others
#  9                           Architecture
#  10                     Trade and economy
#  11                    People and classes
#  12                                People
#
#                                                      1
#  0   Mesoamerican Aztecs Maya Huastec Mixtec P'urhé...
#  1   Aztecs Maya Huastec Mixtec P'urhépecha Totonac...
#  2                         Arawak Ciboney Guanahatabey
#  3   Mission Indians Cahuilla Chumash Cupeño Juaneñ...
#  4   Apache Coahuiltecan Cocopah Comanche Hopi Hual...
#  5     Acaxee Chichimeca Cochimí Kiliwa Opata Tepehuán
#  6   Indigenous people during De Soto's travels Apa...
#  7   Negrito Igorot Mangyan Peoples of Palawan Ati ...
#  8        Taiwanese indigenous peoples Chamorro people
#  9   Spanish Colonial style by country Colonial Bar...
#  10  Real Columbian exchange Manila galleon Triangu...
#  11  Casta Peninsulares Criollo Indios Mestizo Cast...
#  12  Juan Bautista de Anza Juan Rodríguez Cabrillo ...  ,
#                                        0  \
#  0                          Mesoamerican
#  1                             Caribbean
#  2                            California
#  3                          Southwestern
#  4                North-Northwest Mexico
#  5  Florida and otherSoutheastern tribes
#  6                             Filipinos
#  7                                Others
#
#                                                     1
#  0  Aztecs Maya Huastec Mixtec P'urhépecha Totonac...
#  1                        Arawak Ciboney Guanahatabey
#  2  Mission Indians Cahuilla Chumash Cupeño Juaneñ...
#  3  Apache Coahuiltecan Cocopah Comanche Hopi Hual...
#  4    Acaxee Chichimeca Cochimí Kiliwa Opata Tepehuán
#  5  Indigenous people during De Soto's travels Apa...
#  6  Negrito Igorot Mangyan Peoples of Palawan Ati ...
#  7       Taiwanese indigenous peoples Chamorro people  ,
#    vte Political divisions of the United States  \
#  0               List of states and territories
#  1                                       States
#  2                             Federal district
#  3                                Insular areas
#  4                             Outlying islands
#  5                          Indian reservations
#  6                                       Others
#
#        vte Political divisions of the United States.1
#  0                     List of states and territories
#  1  Alabama Alaska Arizona Arkansas California Col...
#  2                                   Washington, D.C.
#  3  American Samoa Guam Northern Mariana Islands P...
#  4  Baker Island Howland Island Jarvis Island John...
#  5                        List of Indian reservations
#  6                                    Federal enclave  ,
#      Authority control                                Authority control.1
#  0             General                             ISNI 1 VIAF 1 WorldCat
#  1  National libraries  France (data) Germany Israel United States Cze...
#  2               Other            MusicBrainz area National Archives (US)]

# %%
print(f'Total tables: {len(table_MN)}')
# Out:
# Total tables: 29

# %%
table_MN[0]
# Out:
#                                             Minnesota  \
# 0                                               State
# 1                                  State of Minnesota
# 2   .mw-parser-output .ib-settlement-cols{text-ali...
# 3   Nickname(s): Land of 10,000 Lakes;North Star S...
# 4   Motto(s): L'Étoile du Nord (French: The Star o...
# 5                           Anthem: "Hail! Minnesota"
# 6   Map of the United States with Minnesota highli...
# 7                                             Country
# 8                                    Before statehood
# 9                               Admitted to the Union
# 10                                            Capital
# 11                                       Largest city
# 12                      Largest metro and urban areas
# 13                                         Government
# 14                                         • Governor
# 15                              • Lieutenant Governor
# 16                                        Legislature
# 17                                      • Upper house
# 18                                      • Lower house
# 19                                          Judiciary
# 20                                      U.S. senators
# 21                              U.S. House delegation
# 22                                               Area
# 23                                            • Total
# 24                                             • Land
# 25                                            • Water
# 26                                             • Rank
# 27                                         Dimensions
# 28                                           • Length
# 29                                            • Width
# 30                                          Elevation
# 31           Highest elevation (Eagle Mountain[1][2])
# 32          Lowest elevation (Lake Superior[1][2][3])
# 33                                  Population (2021)
# 34                                            • Total
# 35                                             • Rank
# 36                                          • Density
# 37                                             • Rank
# 38                          • Median household income
# 39                                      • Income rank
# 40                                         Demonym(s)
# 41                                           Language
# 42                                • Official language
# 43                                  • Spoken language
# 44                                          Time zone
# 45                                     • Summer (DST)
# 46                                  USPS abbreviation
# 47                                      ISO 3166 code
# 48                           Traditional abbreviation
# 49                                           Latitude
# 50                                          Longitude
# 51                                            Website
#
#                                           Minnesota.1
# 0                                               State
# 1                                  State of Minnesota
# 2   .mw-parser-output .ib-settlement-cols{text-ali...
# 3   Nickname(s): Land of 10,000 Lakes;North Star S...
# 4   Motto(s): L'Étoile du Nord (French: The Star o...
# 5                           Anthem: "Hail! Minnesota"
# 6   Map of the United States with Minnesota highli...
# 7                                       United States
# 8                                 Minnesota Territory
# 9              May 11, 1858 (32nd State in the Union)
# 10                                         Saint Paul
# 11                                        Minneapolis
# 12                             Minneapolis–Saint Paul
# 13                                         Government
# 14                                     Tim Walz (DFL)
# 15                               Peggy Flanagan (DFL)
# 16                              Minnesota Legislature
# 17                                             Senate
# 18                           House of Representatives
# 19                            Minnesota Supreme Court
# 20                Amy Klobuchar (DFL)Tina Smith (DFL)
# 21           4 Democrats3 Republicans1 vacancy (list)
# 22                                               Area
# 23                      86,935.83 sq mi (225,163 km2)
# 24                      79,626.74 sq mi (206,232 km2)
# 25                  7,309.09 sq mi (18,930 km2) 8.40%
# 26                                               12th
# 27                                         Dimensions
# 28                              about 400 mi (640 km)
# 29                            200–350 mi (320–560 km)
# 30                                   1,200 ft (370 m)
# 31                                   2,301 ft (701 m)
# 32                                     602 ft (183 m)
# 33                                  Population (2021)
# 34                                       5,707,390[4]
# 35                                               22nd
# 36                              68.9/sq mi (26.6/km2)
# 37                               30th (2015 estimate)
# 38                                         $74,593[5]
# 39                                               13th
# 40                                         Minnesotan
# 41                                           Language
# 42                                               None
# 43              English 88.9% Spanish Somali Hmong[6]
# 44                                UTC−06:00 (Central)
# 45                                    UTC−05:00 (CDT)
# 46                                                 MN
# 47                                              US-MN
# 48                                              Minn.
# 49                             43° 30′ N to 49° 23′ N
# 50                             89° 29′ W to 97° 14′ W
# 51                                             mn.gov

# %%
table_MN[13]
# Out:
#                             0  \
# 0                       Parks
# 1                   Monuments
# 2                      Rivers
# 3               Scenic Trails
# 4             WildlifeRefuges
# 5  WetlandManagementDistricts
# 6                     Forests
# 7            NaturalLandmarks
# 8                  Wilderness
#
#                                                    1
# 0                                          Voyageurs
# 1                            Grand Portage Pipestone
# 2  Mississippi National River and Recreation Area...
# 3                                North Country Trail
# 4  Agassiz Big Stone Crane Meadows Glacial Ridge ...
# 5  Big Stone Detroit Lakes Fergus Falls Litchfiel...
# 6                                  Chippewa Superior
# 7  Ancient River Warren Channel Cedar Creek Ecosy...
# 8         Agassiz Boundary Waters Canoe Area Tamarac

# %%
table_MN = pd.read_html('https://en.wikipedia.org/wiki/Minnesota', match='Election results from statewide races')

# %%
len(table_MN)
# Out:
# 1

# %%
table_MN[0]
# Out:
#     Year     Office    GOP    DFL Others
# 0   2020  President  45.3%  52.4%   2.3%
# 1   2020    Senator  43.5%  48.8%   7.7%
# 2   2018   Governor  42.4%  53.9%   3.7%
# 3   2018    Senator  36.2%  60.3%   3.4%
# 4   2018    Senator  42.4%  53.0%   4.6%
# 5   2016  President  44.9%  46.4%   8.6%
# 6   2014   Governor  44.5%  50.1%   5.4%
# 7   2014    Senator  42.9%  53.2%   3.9%
# 8   2012  President  45.1%  52.8%   2.1%
# 9   2012    Senator  30.6%  65.3%   4.1%
# 10  2010   Governor  43.2%  43.7%  13.1%
# 11  2008  President  43.8%  54.1%   2.1%
# 12  2008    Senator  42.0%  42.0%  16.0%
# 13  2006   Governor  46.7%  45.7%   7.6%
# 14  2006    Senator  37.9%  58.1%   4.0%
# 15  2004  President  47.6%  51.1%   1.3%
# 16  2002   Governor  44.4%  33.5%  22.1%
# 17  2002    Senator  49.5%  47.3%   1.0%
# 18  2000  President  45.5%  47.9%   6.6%
# 19  2000    Senator  43.3%  48.8%   7.9%
# 20  1998   Governor  34.3%  28.1%  37.6%
# 21  1996  President  35.0%  51.1%  13.9%
# 22  1996    Senator  41.3%  50.3%   8.4%
# 23  1994   Governor  63.3%  34.1%   2.6%
# 24  1994    Senator  49.1%  44.1%   6.8%
# 25  1992  President  31.9%  43.5%  24.6%

# %%
df=table_MN[0]
df
# Out:
#     Year     Office    GOP    DFL Others
# 0   2020  President  45.3%  52.4%   2.3%
# 1   2020    Senator  43.5%  48.8%   7.7%
# 2   2018   Governor  42.4%  53.9%   3.7%
# 3   2018    Senator  36.2%  60.3%   3.4%
# 4   2018    Senator  42.4%  53.0%   4.6%
# 5   2016  President  44.9%  46.4%   8.6%
# 6   2014   Governor  44.5%  50.1%   5.4%
# 7   2014    Senator  42.9%  53.2%   3.9%
# 8   2012  President  45.1%  52.8%   2.1%
# 9   2012    Senator  30.6%  65.3%   4.1%
# 10  2010   Governor  43.2%  43.7%  13.1%
# 11  2008  President  43.8%  54.1%   2.1%
# 12  2008    Senator  42.0%  42.0%  16.0%
# 13  2006   Governor  46.7%  45.7%   7.6%
# 14  2006    Senator  37.9%  58.1%   4.0%
# 15  2004  President  47.6%  51.1%   1.3%
# 16  2002   Governor  44.4%  33.5%  22.1%
# 17  2002    Senator  49.5%  47.3%   1.0%
# 18  2000  President  45.5%  47.9%   6.6%
# 19  2000    Senator  43.3%  48.8%   7.9%
# 20  1998   Governor  34.3%  28.1%  37.6%
# 21  1996  President  35.0%  51.1%  13.9%
# 22  1996    Senator  41.3%  50.3%   8.4%
# 23  1994   Governor  63.3%  34.1%   2.6%
# 24  1994    Senator  49.1%  44.1%   6.8%
# 25  1992  President  31.9%  43.5%  24.6%

# %%
#df['GOP'].astype('float')

# %%
#changing value from integer to float, first replace the integer with nothing
df['GOP'].replace({'%':''}, regex=True).astype('float')
# Out:
# 0     45.3
# 1     43.5
# 2     42.4
# 3     36.2
# 4     42.4
# 5     44.9
# 6     44.5
# 7     42.9
# 8     45.1
# 9     30.6
# 10    43.2
# 11    43.8
# 12    42.0
# 13    46.7
# 14    37.9
# 15    47.6
# 16    44.4
# 17    49.5
# 18    45.5
# 19    43.3
# 20    34.3
# 21    35.0
# 22    41.3
# 23    63.3
# 24    49.1
# 25    31.9
# Name: GOP, dtype: float64

# %%
df
# Out:
#     Year     Office    GOP    DFL Others
# 0   2020  President  45.3%  52.4%   2.3%
# 1   2020    Senator  43.5%  48.8%   7.7%
# 2   2018   Governor  42.4%  53.9%   3.7%
# 3   2018    Senator  36.2%  60.3%   3.4%
# 4   2018    Senator  42.4%  53.0%   4.6%
# 5   2016  President  44.9%  46.4%   8.6%
# 6   2014   Governor  44.5%  50.1%   5.4%
# 7   2014    Senator  42.9%  53.2%   3.9%
# 8   2012  President  45.1%  52.8%   2.1%
# 9   2012    Senator  30.6%  65.3%   4.1%
# 10  2010   Governor  43.2%  43.7%  13.1%
# 11  2008  President  43.8%  54.1%   2.1%
# 12  2008    Senator  42.0%  42.0%  16.0%
# 13  2006   Governor  46.7%  45.7%   7.6%
# 14  2006    Senator  37.9%  58.1%   4.0%
# 15  2004  President  47.6%  51.1%   1.3%
# 16  2002   Governor  44.4%  33.5%  22.1%
# 17  2002    Senator  49.5%  47.3%   1.0%
# 18  2000  President  45.5%  47.9%   6.6%
# 19  2000    Senator  43.3%  48.8%   7.9%
# 20  1998   Governor  34.3%  28.1%  37.6%
# 21  1996  President  35.0%  51.1%  13.9%
# 22  1996    Senator  41.3%  50.3%   8.4%
# 23  1994   Governor  63.3%  34.1%   2.6%
# 24  1994    Senator  49.1%  44.1%   6.8%
# 25  1992  President  31.9%  43.5%  24.6%

# %%
df['GOP']=df['GOP'].replace({'%':''}, regex=True)

# %%
df
# Out:
#     Year     Office   GOP    DFL Others
# 0   2020  President  45.3  52.4%   2.3%
# 1   2020    Senator  43.5  48.8%   7.7%
# 2   2018   Governor  42.4  53.9%   3.7%
# 3   2018    Senator  36.2  60.3%   3.4%
# 4   2018    Senator  42.4  53.0%   4.6%
# 5   2016  President  44.9  46.4%   8.6%
# 6   2014   Governor  44.5  50.1%   5.4%
# 7   2014    Senator  42.9  53.2%   3.9%
# 8   2012  President  45.1  52.8%   2.1%
# 9   2012    Senator  30.6  65.3%   4.1%
# 10  2010   Governor  43.2  43.7%  13.1%
# 11  2008  President  43.8  54.1%   2.1%
# 12  2008    Senator  42.0  42.0%  16.0%
# 13  2006   Governor  46.7  45.7%   7.6%
# 14  2006    Senator  37.9  58.1%   4.0%
# 15  2004  President  47.6  51.1%   1.3%
# 16  2002   Governor  44.4  33.5%  22.1%
# 17  2002    Senator  49.5  47.3%   1.0%
# 18  2000  President  45.5  47.9%   6.6%
# 19  2000    Senator  43.3  48.8%   7.9%
# 20  1998   Governor  34.3  28.1%  37.6%
# 21  1996  President  35.0  51.1%  13.9%
# 22  1996    Senator  41.3  50.3%   8.4%
# 23  1994   Governor  63.3  34.1%   2.6%
# 24  1994    Senator  49.1  44.1%   6.8%
# 25  1992  President  31.9  43.5%  24.6%

# %%
df['GOP']=df['GOP'].astype('float')

# %%
df
# Out:
#     Year     Office   GOP    DFL Others
# 0   2020  President  45.3  52.4%   2.3%
# 1   2020    Senator  43.5  48.8%   7.7%
# 2   2018   Governor  42.4  53.9%   3.7%
# 3   2018    Senator  36.2  60.3%   3.4%
# 4   2018    Senator  42.4  53.0%   4.6%
# 5   2016  President  44.9  46.4%   8.6%
# 6   2014   Governor  44.5  50.1%   5.4%
# 7   2014    Senator  42.9  53.2%   3.9%
# 8   2012  President  45.1  52.8%   2.1%
# 9   2012    Senator  30.6  65.3%   4.1%
# 10  2010   Governor  43.2  43.7%  13.1%
# 11  2008  President  43.8  54.1%   2.1%
# 12  2008    Senator  42.0  42.0%  16.0%
# 13  2006   Governor  46.7  45.7%   7.6%
# 14  2006    Senator  37.9  58.1%   4.0%
# 15  2004  President  47.6  51.1%   1.3%
# 16  2002   Governor  44.4  33.5%  22.1%
# 17  2002    Senator  49.5  47.3%   1.0%
# 18  2000  President  45.5  47.9%   6.6%
# 19  2000    Senator  43.3  48.8%   7.9%
# 20  1998   Governor  34.3  28.1%  37.6%
# 21  1996  President  35.0  51.1%  13.9%
# 22  1996    Senator  41.3  50.3%   8.4%
# 23  1994   Governor  63.3  34.1%   2.6%
# 24  1994    Senator  49.1  44.1%   6.8%
# 25  1992  President  31.9  43.5%  24.6%

# %%
df=df.replace({'%':''},regex=True)

# %%
df.head()
# Out:
#    Year     Office   GOP   DFL Others
# 0  2020  President  45.3  52.4    2.3
# 1  2020    Senator  43.5  48.8    7.7
# 2  2018   Governor  42.4  53.9    3.7
# 3  2018    Senator  36.2  60.3    3.4
# 4  2018    Senator  42.4  53.0    4.6

# %%
df[['GOP','DFL','Others']]=df[['GOP','DFL','Others']].apply(pd.to_numeric)

# %%
df
# Out:
#     Year     Office   GOP   DFL  Others
# 0   2020  President  45.3  52.4     2.3
# 1   2020    Senator  43.5  48.8     7.7
# 2   2018   Governor  42.4  53.9     3.7
# 3   2018    Senator  36.2  60.3     3.4
# 4   2018    Senator  42.4  53.0     4.6
# 5   2016  President  44.9  46.4     8.6
# 6   2014   Governor  44.5  50.1     5.4
# 7   2014    Senator  42.9  53.2     3.9
# 8   2012  President  45.1  52.8     2.1
# 9   2012    Senator  30.6  65.3     4.1
# 10  2010   Governor  43.2  43.7    13.1
# 11  2008  President  43.8  54.1     2.1
# 12  2008    Senator  42.0  42.0    16.0
# 13  2006   Governor  46.7  45.7     7.6
# 14  2006    Senator  37.9  58.1     4.0
# 15  2004  President  47.6  51.1     1.3
# 16  2002   Governor  44.4  33.5    22.1
# 17  2002    Senator  49.5  47.3     1.0
# 18  2000  President  45.5  47.9     6.6
# 19  2000    Senator  43.3  48.8     7.9
# 20  1998   Governor  34.3  28.1    37.6
# 21  1996  President  35.0  51.1    13.9
# 22  1996    Senator  41.3  50.3     8.4
# 23  1994   Governor  63.3  34.1     2.6
# 24  1994    Senator  49.1  44.1     6.8
# 25  1992  President  31.9  43.5    24.6

# %%
table_GDP = pd.read_html('https://en.wikipedia.org/wiki/Economy_of_the_United_States')

# %%
df_GDP=table_GDP[3]
df_GDP
# Out:
#     Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0   1980                2857.3                      12552.9
# 1   1981                3207.0                      13948.7
# 2   1982                3343.8                      14405.0
# 3   1983                3634.0                      15513.7
# 4   1984                4037.7                      17086.4
# 5   1985                4339.0                      18199.3
# 6   1986                4579.6                      19034.8
# 7   1987                4855.3                      20001.0
# 8   1988                5236.4                      21376.0
# 9   1989                5641.6                      22814.1
# 10  1990                5963.1                      23848.0
# 11  1991                6158.1                      24302.8
# 12  1992                6520.3                      25392.9
# 13  1993                6858.6                      26364.2
# 14  1994                7287.3                      27674.0
# 15  1995                7639.8                      28671.5
# 16  1996                8073.1                      29947.0
# 17  1997                8577.6                      31440.1
# 18  1998                9062.8                      32833.7
# 19  1999                9631.2                      34496.2
# 20  2000               10251.0                      36312.8
# 21  2001               10581.9                      37101.5
# 22  2002               10929.1                      37945.8
# 23  2003               11456.5                      39405.4
# 24  2004               12217.2                      41641.6
# 25  2005               13039.2                      44034.3
# 26  2006               13815.6                      46216.9
# 27  2007               14474.3                      47943.4
# 28  2008               14769.9                      48470.6
# 29  2009               14478.1                      47102.4
# 30  2010               15049.0                      48586.3
# 31  2011               15599.7                      50008.1
# 32  2012               16254.0                      51736.7
# 33  2013               16843.2                      53245.5
# 34  2014               17550.7                      55083.5
# 35  2015               18206.0                      56729.7
# 36  2016               18695.1                      57840.0
# 37  2017               19479.6                      59885.7
# 38  2018               20527.2                      62769.7
# 39  2019               21372.6                      65051.9
# 40  2020               20893.8                      63358.5
# 41  2021               22939.6                      69375.4
# 42  2022               24796.1                      74725.0
# 43  2023               25938.2                      77881.3
# 44  2024               26980.4                      80714.8
# 45  2025               28035.1                      83563.8
# 46  2026               29102.5                      86428.7
#
#     GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# 0                     2857.3                          12552.9
# 1                     3207.0                          13948.7
# 2                     3343.8                          14405.0
# 3                     3634.0                          15513.7
# 4                     4037.7                          17086.4
# 5                     4339.0                          18199.3
# 6                     4579.6                          19034.8
# 7                     4855.3                          20001.0
# 8                     5236.4                          21376.0
# 9                     5641.6                          22814.1
# 10                    5963.1                          23848.0
# 11                    6158.1                          24302.8
# 12                    6520.3                          25392.9
# 13                    6858.6                          26364.2
# 14                    7287.3                          27674.0
# 15                    7639.8                          28671.5
# 16                    8073.1                          29947.0
# 17                    8577.6                          31440.1
# 18                    9062.8                          32833.7
# 19                    9631.2                          34496.2
# 20                   10251.0                          36312.8
# 21                   10581.9                          37101.5
# 22                   10929.1                          37945.8
# 23                   11456.5                          39405.4
# 24                   12217.2                          41641.6
# 25                   13039.2                          44034.3
# 26                   13815.6                          46216.9
# 27                   14474.3                          47943.4
# 28                   14769.9                          48470.6
# 29                   14478.1                          47102.4
# 30                   15049.0                          48586.3
# 31                   15599.7                          50008.1
# 32                   16254.0                          51736.7
# 33                   16843.2                          53245.5
# 34                   17550.7                          55083.5
# 35                   18206.0                          56729.7
# 36                   18695.1                          57840.0
# 37                   19479.6                          59885.7
# 38                   20527.2                          62769.7
# 39                   21372.6                          65051.9
# 40                   20893.8                          63358.5
# 41                   22939.6                          69375.4
# 42                   24796.1                          74725.0
# 43                   25938.2                          77881.3
# 44                   26980.4                          80714.8
# 45                   28035.1                          83563.8
# 46                   29102.5                          86428.7
#
#    GDP growth (real) Inflation rate (in Percent) Unemployment (in Percent)  \
# 0              -0.3%                       13.5%                      7.2%
# 1               2.5%                       10.4%                      7.6%
# 2              -1.8%                        6.2%                      9.7%
# 3               4.6%                        3.2%                      9.6%
# 4               7.2%                        4.4%                      7.5%
# 5               4.2%                        3.5%                      7.2%
# 6               3.5%                        1.9%                      7.0%
# 7               3.5%                        3.6%                      6.2%
# 8               4.2%                        4.1%                      5.5%
# 9               3.7%                        4.8%                      5.3%
# 10              1.9%                        5.4%                      5.6%
# 11             -0.1%                        4.2%                      6.9%
# 12              3.5%                        3.0%                      7.5%
# 13              2.8%                        3.0%                      6.9%
# 14              4.0%                        2.6%                      6.1%
# 15              2.7%                        2.8%                      5.6%
# 16              3.8%                        2.9%                      5.4%
# 17              4.4%                        2.3%                      4.9%
# 18              4.5%                        1.5%                      4.5%
# 19              4.8%                        2.2%                      4.2%
# 20              4.1%                        3.4%                      4.0%
# 21              1.0%                        2.8%                      4.7%
# 22              1.7%                        1.6%                      5.8%
# 23              2.8%                        2.3%                      6.0%
# 24              3.9%                        2.7%                      5.5%
# 25              3.5%                        3.4%                      5.1%
# 26              2.8%                        3.2%                      4.6%
# 27              2.0%                        2.9%                      4.6%
# 28              0.1%                        3.8%                      5.8%
# 29             -2.6%                       -0.3%                      9.3%
# 30              2.7%                        1.6%                      9.6%
# 31              1.6%                        3.1%                      8.9%
# 32              2.3%                        2.1%                      8.1%
# 33              1.8%                        1.5%                      7.4%
# 34              2.3%                        1.6%                      6.2%
# 35              2.7%                        0.1%                      5.3%
# 36              1.7%                        1.3%                      4.9%
# 37              2.3%                        2.1%                      4.4%
# 38              2.9%                        2.4%                      3.9%
# 39              2.3%                        1.8%                      3.7%
# 40             -3.4%                        1.2%                      8.1%
# 41              6.0%                        4.3%                      5.4%
# 42              5.2%                        3.5%                      3.5%
# 43              2.2%                        2.7%                      3.0%
# 44              1.7%                        2.6%                      3.0%
# 45              1.7%                        2.5%                      3.1%
# 46              1.7%                        2.3%                      3.3%
#
#    Government debt (in % of GDP)
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                         53.1%
# 22                         55.5%
# 23                         58.6%
# 24                         66.1%
# 25                         65.5%
# 26                         64.2%
# 27                         64.6%
# 28                         73.4%
# 29                         86.6%
# 30                         95.1%
# 31                         99.5%
# 32                        103.0%
# 33                        104.5%
# 34                        104.5%
# 35                        104.9%
# 36                        106.9%
# 37                        106.0%
# 38                        107.1%
# 39                        108.5%
# 40                        133.9%
# 41                        133.3%
# 42                        130.7%
# 43                        131.1%
# 44                        131.7%
# 45                        132.5%
# 46                        133.5%

# %%
df_GDP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             47 non-null     int64
#  1   GDP (in Bil. US$PPP)             47 non-null     float64
#  2   GDP per capita (in US$ PPP)      47 non-null     float64
#  3   GDP (in Bil. US$nominal)         47 non-null     float64
#  4   GDP per capita (in US$ nominal)  47 non-null     float64
#  5   GDP growth (real)                47 non-null     object
#  6   Inflation rate (in Percent)      47 non-null     object
#  7   Unemployment (in Percent)        47 non-null     object
#  8   Government debt (in % of GDP)    26 non-null     object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 3.4+ KB

# %%
df_GDP['GDP growth (real)'].replace({'%': ''}, regex=True).astype('float')
# Out:
# 0    -0.3
# 1     2.5
# 2    -1.8
# 3     4.6
# 4     7.2
# 5     4.2
# 6     3.5
# 7     3.5
# 8     4.2
# 9     3.7
# 10    1.9
# 11   -0.1
# 12    3.5
# 13    2.8
# 14    4.0
# 15    2.7
# 16    3.8
# 17    4.4
# 18    4.5
# 19    4.8
# 20    4.1
# 21    1.0
# 22    1.7
# 23    2.8
# 24    3.9
# 25    3.5
# 26    2.8
# 27    2.0
# 28    0.1
# 29   -2.6
# 30    2.7
# 31    1.6
# 32    2.3
# 33    1.8
# 34    2.3
# 35    2.7
# 36    1.7
# 37    2.3
# 38    2.9
# 39    2.3
# 40   -3.4
# 41    6.0
# 42    5.2
# 43    2.2
# 44    1.7
# 45    1.7
# 46    1.7
# Name: GDP growth (real), dtype: float64

# %%
#strip removes extra spaces
from unicodedata import normalize
def clean_normalize_whitespace(x):
    if isinstance(x, str):
        return normalize('NFKC', x).strip()
    else:
        return x

# %%
df_GDP = df_GDP.applymap(clean_normalize_whitespace)

# %%
df_GDP
# Out:
#     Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0   1980                2857.3                      12552.9
# 1   1981                3207.0                      13948.7
# 2   1982                3343.8                      14405.0
# 3   1983                3634.0                      15513.7
# 4   1984                4037.7                      17086.4
# 5   1985                4339.0                      18199.3
# 6   1986                4579.6                      19034.8
# 7   1987                4855.3                      20001.0
# 8   1988                5236.4                      21376.0
# 9   1989                5641.6                      22814.1
# 10  1990                5963.1                      23848.0
# 11  1991                6158.1                      24302.8
# 12  1992                6520.3                      25392.9
# 13  1993                6858.6                      26364.2
# 14  1994                7287.3                      27674.0
# 15  1995                7639.8                      28671.5
# 16  1996                8073.1                      29947.0
# 17  1997                8577.6                      31440.1
# 18  1998                9062.8                      32833.7
# 19  1999                9631.2                      34496.2
# 20  2000               10251.0                      36312.8
# 21  2001               10581.9                      37101.5
# 22  2002               10929.1                      37945.8
# 23  2003               11456.5                      39405.4
# 24  2004               12217.2                      41641.6
# 25  2005               13039.2                      44034.3
# 26  2006               13815.6                      46216.9
# 27  2007               14474.3                      47943.4
# 28  2008               14769.9                      48470.6
# 29  2009               14478.1                      47102.4
# 30  2010               15049.0                      48586.3
# 31  2011               15599.7                      50008.1
# 32  2012               16254.0                      51736.7
# 33  2013               16843.2                      53245.5
# 34  2014               17550.7                      55083.5
# 35  2015               18206.0                      56729.7
# 36  2016               18695.1                      57840.0
# 37  2017               19479.6                      59885.7
# 38  2018               20527.2                      62769.7
# 39  2019               21372.6                      65051.9
# 40  2020               20893.8                      63358.5
# 41  2021               22939.6                      69375.4
# 42  2022               24796.1                      74725.0
# 43  2023               25938.2                      77881.3
# 44  2024               26980.4                      80714.8
# 45  2025               28035.1                      83563.8
# 46  2026               29102.5                      86428.7
#
#     GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# 0                     2857.3                          12552.9
# 1                     3207.0                          13948.7
# 2                     3343.8                          14405.0
# 3                     3634.0                          15513.7
# 4                     4037.7                          17086.4
# 5                     4339.0                          18199.3
# 6                     4579.6                          19034.8
# 7                     4855.3                          20001.0
# 8                     5236.4                          21376.0
# 9                     5641.6                          22814.1
# 10                    5963.1                          23848.0
# 11                    6158.1                          24302.8
# 12                    6520.3                          25392.9
# 13                    6858.6                          26364.2
# 14                    7287.3                          27674.0
# 15                    7639.8                          28671.5
# 16                    8073.1                          29947.0
# 17                    8577.6                          31440.1
# 18                    9062.8                          32833.7
# 19                    9631.2                          34496.2
# 20                   10251.0                          36312.8
# 21                   10581.9                          37101.5
# 22                   10929.1                          37945.8
# 23                   11456.5                          39405.4
# 24                   12217.2                          41641.6
# 25                   13039.2                          44034.3
# 26                   13815.6                          46216.9
# 27                   14474.3                          47943.4
# 28                   14769.9                          48470.6
# 29                   14478.1                          47102.4
# 30                   15049.0                          48586.3
# 31                   15599.7                          50008.1
# 32                   16254.0                          51736.7
# 33                   16843.2                          53245.5
# 34                   17550.7                          55083.5
# 35                   18206.0                          56729.7
# 36                   18695.1                          57840.0
# 37                   19479.6                          59885.7
# 38                   20527.2                          62769.7
# 39                   21372.6                          65051.9
# 40                   20893.8                          63358.5
# 41                   22939.6                          69375.4
# 42                   24796.1                          74725.0
# 43                   25938.2                          77881.3
# 44                   26980.4                          80714.8
# 45                   28035.1                          83563.8
# 46                   29102.5                          86428.7
#
#    GDP growth (real) Inflation rate (in Percent) Unemployment (in Percent)  \
# 0              -0.3%                       13.5%                      7.2%
# 1               2.5%                       10.4%                      7.6%
# 2              -1.8%                        6.2%                      9.7%
# 3               4.6%                        3.2%                      9.6%
# 4               7.2%                        4.4%                      7.5%
# 5               4.2%                        3.5%                      7.2%
# 6               3.5%                        1.9%                      7.0%
# 7               3.5%                        3.6%                      6.2%
# 8               4.2%                        4.1%                      5.5%
# 9               3.7%                        4.8%                      5.3%
# 10              1.9%                        5.4%                      5.6%
# 11             -0.1%                        4.2%                      6.9%
# 12              3.5%                        3.0%                      7.5%
# 13              2.8%                        3.0%                      6.9%
# 14              4.0%                        2.6%                      6.1%
# 15              2.7%                        2.8%                      5.6%
# 16              3.8%                        2.9%                      5.4%
# 17              4.4%                        2.3%                      4.9%
# 18              4.5%                        1.5%                      4.5%
# 19              4.8%                        2.2%                      4.2%
# 20              4.1%                        3.4%                      4.0%
# 21              1.0%                        2.8%                      4.7%
# 22              1.7%                        1.6%                      5.8%
# 23              2.8%                        2.3%                      6.0%
# 24              3.9%                        2.7%                      5.5%
# 25              3.5%                        3.4%                      5.1%
# 26              2.8%                        3.2%                      4.6%
# 27              2.0%                        2.9%                      4.6%
# 28              0.1%                        3.8%                      5.8%
# 29             -2.6%                       -0.3%                      9.3%
# 30              2.7%                        1.6%                      9.6%
# 31              1.6%                        3.1%                      8.9%
# 32              2.3%                        2.1%                      8.1%
# 33              1.8%                        1.5%                      7.4%
# 34              2.3%                        1.6%                      6.2%
# 35              2.7%                        0.1%                      5.3%
# 36              1.7%                        1.3%                      4.9%
# 37              2.3%                        2.1%                      4.4%
# 38              2.9%                        2.4%                      3.9%
# 39              2.3%                        1.8%                      3.7%
# 40             -3.4%                        1.2%                      8.1%
# 41              6.0%                        4.3%                      5.4%
# 42              5.2%                        3.5%                      3.5%
# 43              2.2%                        2.7%                      3.0%
# 44              1.7%                        2.6%                      3.0%
# 45              1.7%                        2.5%                      3.1%
# 46              1.7%                        2.3%                      3.3%
#
#    Government debt (in % of GDP)
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                         53.1%
# 22                         55.5%
# 23                         58.6%
# 24                         66.1%
# 25                         65.5%
# 26                         64.2%
# 27                         64.6%
# 28                         73.4%
# 29                         86.6%
# 30                         95.1%
# 31                         99.5%
# 32                        103.0%
# 33                        104.5%
# 34                        104.5%
# 35                        104.9%
# 36                        106.9%
# 37                        106.0%
# 38                        107.1%
# 39                        108.5%
# 40                        133.9%
# 41                        133.3%
# 42                        130.7%
# 43                        131.1%
# 44                        131.7%
# 45                        132.5%
# 46                        133.5%

# %%
df_GDP.columns[8]
# Out:
# 'Government debt (in\xa0% of GDP)'

# %%
df_GDP.columns = df_GDP.columns.to_series().apply(clean_normalize_whitespace)
df_GDP.columns[8]
# Out:
# 'Government debt (in % of GDP)'

# %%
df_GDP.columns[8]
# Out:
# 'Government debt (in % of GDP)'

# %%
df_GDP['GDP growth (real)'].replace({'%': ''}, regex=True).astype('float')
# Out:
# 0    -0.3
# 1     2.5
# 2    -1.8
# 3     4.6
# 4     7.2
# 5     4.2
# 6     3.5
# 7     3.5
# 8     4.2
# 9     3.7
# 10    1.9
# 11   -0.1
# 12    3.5
# 13    2.8
# 14    4.0
# 15    2.7
# 16    3.8
# 17    4.4
# 18    4.5
# 19    4.8
# 20    4.1
# 21    1.0
# 22    1.7
# 23    2.8
# 24    3.9
# 25    3.5
# 26    2.8
# 27    2.0
# 28    0.1
# 29   -2.6
# 30    2.7
# 31    1.6
# 32    2.3
# 33    1.8
# 34    2.3
# 35    2.7
# 36    1.7
# 37    2.3
# 38    2.9
# 39    2.3
# 40   -3.4
# 41    6.0
# 42    5.2
# 43    2.2
# 44    1.7
# 45    1.7
# 46    1.7
# Name: GDP growth (real), dtype: float64

# %%
df_GDP['GDP growth (real)']=df_GDP['GDP growth (real)'].replace({'%': ''}, regex=True)

# %%
df_GDP['GDP growth (real)']
# Out:
# 0     -0.3
# 1      2.5
# 2     -1.8
# 3      4.6
# 4      7.2
# 5      4.2
# 6      3.5
# 7      3.5
# 8      4.2
# 9      3.7
# 10     1.9
# 11    -0.1
# 12     3.5
# 13     2.8
# 14     4.0
# 15     2.7
# 16     3.8
# 17     4.4
# 18     4.5
# 19     4.8
# 20     4.1
# 21     1.0
# 22     1.7
# 23     2.8
# 24     3.9
# 25     3.5
# 26     2.8
# 27     2.0
# 28     0.1
# 29    -2.6
# 30     2.7
# 31     1.6
# 32     2.3
# 33     1.8
# 34     2.3
# 35     2.7
# 36     1.7
# 37     2.3
# 38     2.9
# 39     2.3
# 40    -3.4
# 41     6.0
# 42     5.2
# 43     2.2
# 44     1.7
# 45     1.7
# 46     1.7
# Name: GDP growth (real), dtype: object

# %%
df_GDP['GDP growth (real)'].replace({'%':'','-':'-'}, regex=True).astype('float')
# Out:
# 0    -0.3
# 1     2.5
# 2    -1.8
# 3     4.6
# 4     7.2
# 5     4.2
# 6     3.5
# 7     3.5
# 8     4.2
# 9     3.7
# 10    1.9
# 11   -0.1
# 12    3.5
# 13    2.8
# 14    4.0
# 15    2.7
# 16    3.8
# 17    4.4
# 18    4.5
# 19    4.8
# 20    4.1
# 21    1.0
# 22    1.7
# 23    2.8
# 24    3.9
# 25    3.5
# 26    2.8
# 27    2.0
# 28    0.1
# 29   -2.6
# 30    2.7
# 31    1.6
# 32    2.3
# 33    1.8
# 34    2.3
# 35    2.7
# 36    1.7
# 37    2.3
# 38    2.9
# 39    2.3
# 40   -3.4
# 41    6.0
# 42    5.2
# 43    2.2
# 44    1.7
# 45    1.7
# 46    1.7
# Name: GDP growth (real), dtype: float64

# %%
#if your data have any character
df['Year'].replace({'%': '', '−': '-', '\(est\)': ''}, regex=True).astype('int')
# Out:
# 0     2020
# 1     2020
# 2     2018
# 3     2018
# 4     2018
# 5     2016
# 6     2014
# 7     2014
# 8     2012
# 9     2012
# 10    2010
# 11    2008
# 12    2008
# 13    2006
# 14    2006
# 15    2004
# 16    2002
# 17    2002
# 18    2000
# 19    2000
# 20    1998
# 21    1996
# 22    1996
# 23    1994
# 24    1994
# 25    1992
# Name: Year, dtype: int32

# %%
#change the columns according to the recent one(dict.fromkeys(df_GDP.columns, 'float'))
col_type = {
'Year': 'int',
 'GDP (in Bil. US$PPP)': 'float',
 'GDP per capita (in US$ PPP)': 'float',
 'GDP (in Bil. US$nominal)': 'float',
 'GDP per capita (in US$ nominal)': 'float',
 'GDP growth (real)': 'float',
 'Inflation rate (in Percent)': 'float',
 'Unemployment (in Percent)': 'float',
 'Government debt (in % of GDP)': 'float'
}

# %%
dict.fromkeys(df_GDP.columns, 'float')
# Out:
# {'Year': 'float',
#  'GDP (in Bil. US$PPP)': 'float',
#  'GDP per capita (in US$ PPP)': 'float',
#  'GDP (in Bil. US$nominal)': 'float',
#  'GDP per capita (in US$ nominal)': 'float',
#  'GDP growth (real)': 'float',
#  'Inflation rate (in Percent)': 'float',
#  'Unemployment (in Percent)': 'float',
#  'Government debt (in % of GDP)': 'float'}

# %%
clean_dict = {'%': '', '−': '-', '\(est\)': ''}

# %%
df_GDP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             47 non-null     int64
#  1   GDP (in Bil. US$PPP)             47 non-null     float64
#  2   GDP per capita (in US$ PPP)      47 non-null     float64
#  3   GDP (in Bil. US$nominal)         47 non-null     float64
#  4   GDP per capita (in US$ nominal)  47 non-null     float64
#  5   GDP growth (real)                47 non-null     object
#  6   Inflation rate (in Percent)      47 non-null     object
#  7   Unemployment (in Percent)        47 non-null     object
#  8   Government debt (in % of GDP)    26 non-null     object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 3.4+ KB

# %%
df_GDP = df_GDP.replace(clean_dict, regex=True).replace({ '-n/a ': np.nan}).astype(col_type)

# %%
df_GDP.columns
# Out:
# Index(['Year', 'GDP (in Bil. US$PPP)', 'GDP per capita (in US$ PPP)',
#        'GDP (in Bil. US$nominal)', 'GDP per capita (in US$ nominal)',
#        'GDP growth (real)', 'Inflation rate (in Percent)',
#        'Unemployment (in Percent)', 'Government debt (in % of GDP)'],
#       dtype='object')

# %%
plt.style.use('seaborn-whitegrid')
df_GDP.plot.line(x='Year', y=['Inflation rate (in Percent)', 'Unemployment (in Percent)'])
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
mtcars = pd.read_csv('mtcars_analysis.csv')

# %%
mtcars
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
#
#     gear  carb
# 0      4     4
# 1      4     4
# 2      4     1
# 3      3     1
# 4      3     2
# 5      3     1
# 6      3     4
# 7      4     2
# 8      4     2
# 9      4     4
# 10     4     4
# 11     3     3
# 12     3     3
# 13     3     3
# 14     3     4
# 15     3     4
# 16     3     4
# 17     4     1
# 18     4     2
# 19     4     1
# 20     3     1
# 21     3     2
# 22     3     2
# 23     3     4
# 24     3     2
# 25     4     1
# 26     5     2
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %%
mtcars=mtcars.rename(columns={'Unnamed: 0':'model'})

# %%
mtcars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
#
#     gear  carb
# 0      4     4
# 1      4     4
# 2      4     1
# 3      3     1
# 4      3     2
# 5      3     1
# 6      3     4
# 7      4     2
# 8      4     2
# 9      4     4
# 10     4     4
# 11     3     3
# 12     3     3
# 13     3     3
# 14     3     4
# 15     3     4
# 16     3     4
# 17     4     1
# 18     4     2
# 19     4     1
# 20     3     1
# 21     3     2
# 22     3     2
# 23     3     4
# 24     3     2
# 25     4     1
# 26     5     2
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %%
mtcars.index=mtcars.model

# %%
mtcars
# Out:
#                                    model   mpg  cyl   disp   hp  drat     wt  \
# model
# Mazda RX4                      Mazda RX4  21.0    6  160.0  110  3.90  2.620
# Mazda RX4 Wag              Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875
# Datsun 710                    Datsun 710  22.8    4  108.0   93  3.85  2.320
# Hornet 4 Drive            Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215
# Hornet Sportabout      Hornet Sportabout  18.7    8  360.0  175  3.15  3.440
# Valiant                          Valiant  18.1    6  225.0  105  2.76  3.460
# Duster 360                    Duster 360  14.3    8  360.0  245  3.21  3.570
# Merc 240D                      Merc 240D  24.4    4  146.7   62  3.69  3.190
# Merc 230                        Merc 230  22.8    4  140.8   95  3.92  3.150
# Merc 280                        Merc 280  19.2    6  167.6  123  3.92  3.440
# Merc 280C                      Merc 280C  17.8    6  167.6  123  3.92  3.440
# Merc 450SE                    Merc 450SE  16.4    8  275.8  180  3.07  4.070
# Merc 450SL                    Merc 450SL  17.3    8  275.8  180  3.07  3.730
# Merc 450SLC                  Merc 450SLC  15.2    8  275.8  180  3.07  3.780
# Cadillac Fleetwood    Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250
# Lincoln Continental  Lincoln Continental  10.4    8  460.0  215  3.00  5.424
# Chrysler Imperial      Chrysler Imperial  14.7    8  440.0  230  3.23  5.345
# Fiat 128                        Fiat 128  32.4    4   78.7   66  4.08  2.200
# Honda Civic                  Honda Civic  30.4    4   75.7   52  4.93  1.615
# Toyota Corolla            Toyota Corolla  33.9    4   71.1   65  4.22  1.835
# Toyota Corona              Toyota Corona  21.5    4  120.1   97  3.70  2.465
# Dodge Challenger        Dodge Challenger  15.5    8  318.0  150  2.76  3.520
# AMC Javelin                  AMC Javelin  15.2    8  304.0  150  3.15  3.435
# Camaro Z28                    Camaro Z28  13.3    8  350.0  245  3.73  3.840
# Pontiac Firebird        Pontiac Firebird  19.2    8  400.0  175  3.08  3.845
# Fiat X1-9                      Fiat X1-9  27.3    4   79.0   66  4.08  1.935
# Porsche 914-2              Porsche 914-2  26.0    4  120.3   91  4.43  2.140
# Lotus Europa                Lotus Europa  30.4    4   95.1  113  3.77  1.513
# Ford Pantera L            Ford Pantera L  15.8    8  351.0  264  4.22  3.170
# Ferrari Dino                Ferrari Dino  19.7    6  145.0  175  3.62  2.770
# Maserati Bora              Maserati Bora  15.0    8  301.0  335  3.54  3.570
# Volvo 142E                    Volvo 142E  21.4    4  121.0  109  4.11  2.780
#
#                       qsec  vs  am  gear  carb
# model
# Mazda RX4            16.46   0   1     4     4
# Mazda RX4 Wag        17.02   0   1     4     4
# Datsun 710           18.61   1   1     4     1
# Hornet 4 Drive       19.44   1   0     3     1
# Hornet Sportabout    17.02   0   0     3     2
# Valiant              20.22   1   0     3     1
# Duster 360           15.84   0   0     3     4
# Merc 240D            20.00   1   0     4     2
# Merc 230             22.90   1   0     4     2
# Merc 280             18.30   1   0     4     4
# Merc 280C            18.90   1   0     4     4
# Merc 450SE           17.40   0   0     3     3
# Merc 450SL           17.60   0   0     3     3
# Merc 450SLC          18.00   0   0     3     3
# Cadillac Fleetwood   17.98   0   0     3     4
# Lincoln Continental  17.82   0   0     3     4
# Chrysler Imperial    17.42   0   0     3     4
# Fiat 128             19.47   1   1     4     1
# Honda Civic          18.52   1   1     4     2
# Toyota Corolla       19.90   1   1     4     1
# Toyota Corona        20.01   1   0     3     1
# Dodge Challenger     16.87   0   0     3     2
# AMC Javelin          17.30   0   0     3     2
# Camaro Z28           15.41   0   0     3     4
# Pontiac Firebird     17.05   0   0     3     2
# Fiat X1-9            18.90   1   1     4     1
# Porsche 914-2        16.70   0   1     5     2
# Lotus Europa         16.90   1   1     5     2
# Ford Pantera L       14.50   0   1     5     4
# Ferrari Dino         15.50   0   1     5     6
# Maserati Bora        14.60   0   1     5     8
# Volvo 142E           18.60   1   1     4     2

# %%
del mtcars['model']

# %%
mtcars
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# Merc 450SE           16.4    8  275.8  180  3.07  4.070  17.40   0   0     3
# Merc 450SL           17.3    8  275.8  180  3.07  3.730  17.60   0   0     3
# Merc 450SLC          15.2    8  275.8  180  3.07  3.780  18.00   0   0     3
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3
# Chrysler Imperial    14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Fiat 128             32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# Honda Civic          30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# Toyota Corolla       33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# Toyota Corona        21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# Dodge Challenger     15.5    8  318.0  150  2.76  3.520  16.87   0   0     3
# AMC Javelin          15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Camaro Z28           13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Pontiac Firebird     19.2    8  400.0  175  3.08  3.845  17.05   0   0     3
# Fiat X1-9            27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# Porsche 914-2        26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# Lotus Europa         30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# Ford Pantera L       15.8    8  351.0  264  4.22  3.170  14.50   0   1     5
# Ferrari Dino         19.7    6  145.0  175  3.62  2.770  15.50   0   1     5
# Maserati Bora        15.0    8  301.0  335  3.54  3.570  14.60   0   1     5
# Volvo 142E           21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
#
#                      carb
# model
# Mazda RX4               4
# Mazda RX4 Wag           4
# Datsun 710              1
# Hornet 4 Drive          1
# Hornet Sportabout       2
# Valiant                 1
# Duster 360              4
# Merc 240D               2
# Merc 230                2
# Merc 280                4
# Merc 280C               4
# Merc 450SE              3
# Merc 450SL              3
# Merc 450SLC             3
# Cadillac Fleetwood      4
# Lincoln Continental     4
# Chrysler Imperial       4
# Fiat 128                1
# Honda Civic             2
# Toyota Corolla          1
# Toyota Corona           1
# Dodge Challenger        2
# AMC Javelin             2
# Camaro Z28              4
# Pontiac Firebird        2
# Fiat X1-9               1
# Porsche 914-2           2
# Lotus Europa            2
# Ford Pantera L          4
# Ferrari Dino            6
# Maserati Bora           8
# Volvo 142E              2

# %%
mtcars.mean()
# Out:
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
mtcars.mean(axis=0)
# Out:
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
mtcars.mean(axis=1)
# Out:
# model
# Mazda RX4              29.907273
# Mazda RX4 Wag          29.981364
# Datsun 710             23.598182
# Hornet 4 Drive         38.739545
# Hornet Sportabout      53.664545
# Valiant                35.049091
# Duster 360             59.720000
# Merc 240D              24.634545
# Merc 230               27.233636
# Merc 280               31.860000
# Merc 280C              31.787273
# Merc 450SE             46.430909
# Merc 450SL             46.500000
# Merc 450SLC            46.350000
# Cadillac Fleetwood     66.232727
# Lincoln Continental    66.058545
# Chrysler Imperial      65.972273
# Fiat 128               19.440909
# Honda Civic            17.742273
# Toyota Corolla         18.814091
# Toyota Corona          24.888636
# Dodge Challenger       47.240909
# AMC Javelin            46.007727
# Camaro Z28             58.752727
# Pontiac Firebird       57.379545
# Fiat X1-9              18.928636
# Porsche 914-2          24.779091
# Lotus Europa           24.880273
# Ford Pantera L         60.971818
# Ferrari Dino           34.508182
# Maserati Bora          63.155455
# Volvo 142E             26.262727
# dtype: float64

# %%
mtcars.median()
# Out:
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.710
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %%
mtcars.median(axis=1)
# Out:
# model
# Mazda RX4              4.000
# Mazda RX4 Wag          4.000
# Datsun 710             4.000
# Hornet 4 Drive         3.215
# Hornet Sportabout      3.440
# Valiant                3.460
# Duster 360             4.000
# Merc 240D              4.000
# Merc 230               4.000
# Merc 280               4.000
# Merc 280C              4.000
# Merc 450SE             4.070
# Merc 450SL             3.730
# Merc 450SLC            3.780
# Cadillac Fleetwood     5.250
# Lincoln Continental    5.424
# Chrysler Imperial      5.345
# Fiat 128               4.000
# Honda Civic            4.000
# Toyota Corolla         4.000
# Toyota Corona          3.700
# Dodge Challenger       3.520
# AMC Javelin            3.435
# Camaro Z28             4.000
# Pontiac Firebird       3.845
# Fiat X1-9              4.000
# Porsche 914-2          4.430
# Lotus Europa           4.000
# Ford Pantera L         5.000
# Ferrari Dino           6.000
# Maserati Bora          8.000
# Volvo 142E             4.000
# dtype: float64

# %%
norm_data = pd.DataFrame(np.random.normal(size=100000))
norm_data.plot(kind="density",
 figsize=(10,10));
plt.vlines(norm_data.mean(), # Plot black line at mean
 ymin=0,
 ymax=0.4,
 linewidth=5.0);
plt.vlines(norm_data.median(), # Plot red line at median
 ymin=0,
 ymax=0.4,
 linewidth=2.0,
 color="red");

# %%
skewed_data = pd.DataFrame(np.random.exponential(size=100000))
skewed_data.plot(kind="density",
 figsize=(10,10),
 xlim=(-1,5));
plt.vlines(skewed_data.mean(), # Plot black line at mean
 ymin=0,
 ymax=0.8,
 linewidth=5.0);
plt.vlines(skewed_data.median(), # Plot red line at median
 ymin=0,
 ymax=0.8,
 linewidth=2.0,
 color="red");

# %%
norm_data = np.random.normal(size=50)
outliers = np.random.normal(15, size=3)
combined_data = pd.DataFrame(np.concatenate((norm_data, outliers), axis=0))
combined_data.plot(kind="density",
 figsize=(10,10),
 xlim=(-5,20));
plt.vlines(combined_data.mean(), # Plot black line at mean
 ymin=0,
 ymax=0.2,
 linewidth=5.0);
plt.vlines(combined_data.median(), # Plot red line at median
 ymin=0,
 ymax=0.2,
 linewidth=2.0,
 color="red");

# %%
mtcars.mode()
# Out:
#     mpg  cyl   disp     hp  drat    wt   qsec   vs   am  gear  carb
# 0  10.4  8.0  275.8  110.0  3.07  3.44  17.02  0.0  0.0   3.0   2.0
# 1  15.2  NaN    NaN  175.0  3.92   NaN  18.90  NaN  NaN   NaN   4.0
# 2  19.2  NaN    NaN  180.0   NaN   NaN    NaN  NaN  NaN   NaN   NaN
# 3  21.0  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN   NaN   NaN
# 4  21.4  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN   NaN   NaN
# 5  22.8  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN   NaN   NaN
# 6  30.4  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN   NaN   NaN

# %%
max(mtcars["mpg"])
# Out:
# 33.9

# %%
min(mtcars["mpg"])
# Out:
# 10.4

# %%
max(mtcars["mpg"])-min(mtcars["mpg"])
# Out:
# 23.5

# %%
five_num = [mtcars["mpg"].quantile(0), 
 mtcars["mpg"].quantile(0.25),
 mtcars["mpg"].quantile(0.50),
 mtcars["mpg"].quantile(0.75),
 mtcars["mpg"].quantile(1)]
five_num
# Out:
# [10.4, 15.425, 19.2, 22.8, 33.9]

# %%
mtcars["mpg"].describe()
# Out:
# count    32.000000
# mean     20.090625
# std       6.026948
# min      10.400000
# 25%      15.425000
# 50%      19.200000
# 75%      22.800000
# max      33.900000
# Name: mpg, dtype: float64

# %%
mtcars["mpg"].quantile(0.75) - mtcars["mpg"].quantile(0.25)
# Out:
# 7.375

# %%
mtcars.boxplot(column="mpg",
 return_type='axes',
 figsize=(8,8))
# Out:
# <AxesSubplot:>

# %%
mtcars["mpg"].quantile(0.75)-mtcars["mpg"].quantile(0.25)
# Out:
# 7.375

# %%
mtcars["mpg"].var()
# Out:
# 36.32410282258065

# %%
mtcars["mpg"].std()
# Out:
# 6.026948052089105

# %%
abs_median_devs = abs(mtcars["mpg"] - mtcars["mpg"].median())
abs_median_devs.median() * 1.4826
# Out:
# 5.411490000000001

# %%
mtcars["mpg"].skew() # Check skewness
# Out:
# 0.6723771376290805

# %%
mtcars["mpg"].kurt() # Check kurtosis
# Out:
# -0.0220062914240855

# %%
norm_data = np.random.normal(size=100000)
skewed_data = np.concatenate((np.random.normal(size=35000)+2,
 np.random.exponential(size=65000)),
axis=0)
uniform_data = np.random.uniform(0,2, size=100000)
peaked_data = np.concatenate((np.random.exponential(size=50000),
 np.random.exponential(size=50000)*(-1)),
axis=0)
data_df = pd.DataFrame({"norm":norm_data,
 "skewed":skewed_data,
"uniform":uniform_data,
"peaked":peaked_data})

# %%
data_df.plot(kind="density",
 figsize=(10,10),
 xlim=(-5,5));

# %%
data_df.skew()
# Out:
# norm       0.000344
# skewed     1.029248
# uniform    0.004356
# peaked     0.010979
# dtype: float64

# %%
data_df.kurt()
# Out:
# norm      -0.017676
# skewed     1.440956
# uniform   -1.200284
# peaked     2.927368
# dtype: float64

# %%
#Question 1. Find any other HTML data table online that potentially can be useful for 
#your assignments project. Read it using read_html() function and apply appropriate 
#cleaning.

table_bd = table_MN = pd.read_html('https://en.wikipedia.org/wiki/Economy_of_Bangladesh')
table_bd
# Out:
# [                                                    0  \
#  0           Dhaka, the financial centre of Bangladesh
#  1                                            Currency
#  2                                         Fiscal year
#  3                                 Trade organizations
#  4                                       Country group
#  5                                          Statistics
#  6                                          Population
#  7                                                 GDP
#  8                                            GDP rank
#  9                                          GDP growth
#  10                                     GDP per capita
#  11                                GDP per capita rank
#  12                                      GDP by sector
#  13                                    Inflation (CPI)
#  14                      Population below poverty line
#  15                                   Gini coefficient
#  16                            Human Development Index
#  17                                        Labor force
#  18                          Labor force by occupation
#  19                                       Unemployment
#  20                                    Main industries
#  21                        Ease-of-doing-business rank
#  22                                           External
#  23                                            Exports
#  24                               Main export partners
#  25                                            Imports
#  26                                       Import goods
#  27                               Main import partners
#  28                                          FDI stock
#  29                                    Current account
#  30                                Gross external debt
#  31                                    Public finances
#  32                                        Public debt
#  33                                     Budget balance
#  34                                           Revenues
#  35                                           Expenses
#  36                                      Credit rating
#  37                                   Foreign reserves
#  38  Main data source: CIA World Fact Book All valu...
#
#                                                      1
#  0           Dhaka, the financial centre of Bangladesh
#  1                           Bangladeshi taka (BDT, ৳)
#  2                                    1 July – 30 June
#  3   SAFTA, SAARC, BIMSTEC, WTO, AIIB, IMF, Commonw...
#  4   Developing/Emerging[1] Lower-middle income eco...
#  5                                          Statistics
#  6                          162,650,853 (2020 est.)[3]
#  7   $416 billion (nominal; 2021) [4]  $1.07 trilli...
#  8               33rd (nominal, 2021) 31st (PPP, 2021)
#  9   7.9% (17/18) 8.2% (18/19e) 5.2% (19/20f) 6.8% ...
#  10  $2,591 (nominal, 2021)[4]  $6,380 (PPP, 2021 e...
#  11            149th (nominal, 2021) 130th (PPP, 2021)
#  12  agriculture: 14.23% industry: 35.66% services:...
#  13                                5.5% (2020 est.)[9]
#  14  20.5% in poverty (2019)[10][11]  28.3% on less...
#  15                 32.4 medium (2016, World Bank)[15]
#  16  0.632 medium (2019)[16] (133th)  0.478 Low IHD...
#  17  69,706,733 (2019)[18]  55.8% employment rate (...
#  18  agriculture: 40.6% industry: 20.4% services: 3...
#  19  Overall 4.2% Male 3.1% Female 6.7% (2017 est.)...
#  20  Textilespharmaceutical productselectronicsship...
#  21                    168th (below average, 2020)[22]
#  22                                           External
#  23                          $39.14 billion (2021)[23]
#  24  European Union(+) 58.2% United States(+) 16.3%...
#  25                     $60.68 billion (2020-2021)[25]
#  26  Textiles and Textile Articles, Machinery and M...
#  27  China(+) 21.5% India(+) 12.2% Singapore(+) 9.2...
#  28  $16.85 billion (March 2020 est.)[27][28]  Abro...
#  29                 −$3.808 billion US$(2020-21)[25]}}
#  30                $72.1 billion (March 2021 est.)[30]
#  31                                    Public finances
#  32                  40.7% of GDP (November 2021 )[31]
#  33                     −3.2% (of GDP) (2017 est.)[29]
#  34         ৳3.925 trillion (US$46 billion) (2021)[32]
#  35         ৳6.037 trillion (US$71 billion) (2021)[32]
#  36  List of ratings  Standard & Poor's:[33] BB− (D...
#  37               $48 billion (August 2021)[36] (41st)
#  38  Main data source: CIA World Fact Book All valu...  ,
#     Year  Gross Domestic Product (Million Taka) US Dollar Exchange  \
#  0  1980                                 250300         16.10 Taka
#  1  1985                                 597318         31.00 Taka
#  2  1990                                1054234         35.79 Taka
#  3  1995                                1594210         40.27 Taka
#  4  2000                                2453160         52.14 Taka
#  5  2005                                3913334         63.92 Taka
#  6  2008                                5003438         68.65 Taka
#  7  2015                               17295665        78.15 Taka.
#  8  2019                               26604164        84.55 Taka.
#
#     Inflation Index(2000=100)  Per Capita Income(as % of USA)
#  0                       20.0                            1.79
#  1                       36.0                            1.19
#  2                       58.0                            1.16
#  3                       78.0                            1.12
#  4                      100.0                            0.97
#  5                      126.0                            0.95
#  6                      147.0                             NaN
#  7                      196.0                            2.48
#  8                        NaN                            2.91  ,
#      Year  GDP(in bn. US$ PPP)  GDP per capita(in US$ PPP) GDP growth(real)  \
#  0   1980                 41.2                         500            3.1 %
#  1   1981                 47.4                         560            5.6 %
#  2   1982                 52.0                         597            3.2 %
#  3   1983                 56.5                         633            4.6 %
#  4   1984                 61.0                         664            4.2 %
#  5   1985                 65.3                         693            3.7 %
#  6   1986                 69.3                         715            4.0 %
#  7   1987                 73.1                         735            2.9 %
#  8   1988                 77.5                         759            2.4 %
#  9   1989                 84.0                         801            4.3 %
#  10  1990                 91.1                         848            4.6 %
#  11  1991                 98.1                         892            4.2 %
#  12  1992                105.1                         935            4.8 %
#  13  1993                112.3                         977            4.3 %
#  14  1994                119.9                        1021            4.5 %
#  15  1995                128.2                        1069            4.8 %
#  16  1996                137.1                        1120            5.0 %
#  17  1997                146.8                        1175            5.3 %
#  18  1998                155.9                        1223            5.0 %
#  19  1999                166.9                        1284            5.4 %
#  20  2000                180.2                        1361            5.6 %
#  21  2001                193.2                        1434            4.8 %
#  22  2002                205.7                        1501            4.8 %
#  23  2003                221.9                        1594            5.8 %
#  24  2004                241.9                        1713            6.1 %
#  25  2005                265.5                        1855            6.3 %
#  26  2006                292.4                        2018            6.9 %
#  27  2007                319.7                        2183            6.5 %
#  28  2008                344.0                        2325            5.5 %
#  29  2009                365.0                        2441            5.3 %
#  30  2010                391.7                        2592            6.0 %
#  31  2011                425.8                        2785            6.5 %
#  32  2012                460.8                        2979            6.3 %
#  33  2013                496.5                        3171            6.0 %
#  34  2014                537.3                        3396            6.3 %
#  35  2015                581.6                        3638            6.8 %
#  36  2016                629.9                        3900            7.2 %
#  37  2017                710.5                        4331            7.6 %
#  38  2018                785.9                        4730            7.9 %
#  39  2019                869.4                        5228             8.1%
#
#     Inflation rate(in Percent) Unemployment Rate (in Percent)  \
#  0                      15.4 %                            NaN
#  1                      14.5 %                            NaN
#  2                      12.9 %                            NaN
#  3                       9.5 %                            NaN
#  4                      10.4 %                            NaN
#  5                      10.5 %                            NaN
#  6                      10.2 %                            NaN
#  7                      10.8 %                            NaN
#  8                       9.7 %                            NaN
#  9                       8.7 %                            NaN
#  10                     10.5 %                            NaN
#  11                      8.3 %                         2.20 %
#  12                      3.6 %                         2.25 %
#  13                      3.0 %                         2.37 %
#  14                      6.2 %                         2.44 %
#  15                     10.1 %                         2.48 %
#  16                      2.5 %                         2.51 %
#  17                      5.0 %                         2.69 %
#  18                      8.6 %                         2.83 %
#  19                      6.2 %                         3.10 %
#  20                      2.5 %                         3.27 %
#  21                      1.9 %                         3.55 %
#  22                      3.7 %                         3.96 %
#  23                      5.4 %                         4.32 %
#  24                      6.1 %                         4.30 %
#  25                      7.0 %                         4.25 %
#  26                      6.8 %                         3.59 %
#  27                      9.1 %                         3.77 %
#  28                      8.9 %                         4.07 %
#  29                      4.9 %                         5.00 %
#  30                      9.4 %                         3.37 %
#  31                     11.5 %                         3.71 %
#  32                      6.2 %                         4.04 %
#  33                      7.5 %                         4.43 %
#  34                      7.0 %                         4.41 %
#  35                      6.2 %                         4.42 %
#  36                      5.7 %                         4.35 %
#  37                      5.6 %                         4.37 %
#  38                      5.6 %                         4.30 %
#  39                       5.5%                         4.29 %
#
#     Government debt(in % of GDP) Total Investment (in % of GDP)
#  0                           NaN                        14.44 %
#  1                           NaN                        17.16 %
#  2                           NaN                         17.36%
#  3                           NaN                        16.56 %
#  4                           NaN                        16.48 %
#  5                           NaN                        15.83 %
#  6                           NaN                        16.18 %
#  7                           NaN                        15.47 %
#  8                           NaN                        15.74 %
#  9                           NaN                        16.12 %
#  10                          NaN                        16.46 %
#  11                          NaN                        16.90 %
#  12                          NaN                        17.31 %
#  13                          NaN                        17.95 %
#  14                          NaN                        18.40 %
#  15                          NaN                        19.12 %
#  16                          NaN                        20.73 %
#  17                          NaN                        21.82 %
#  18                          NaN                        22.12 %
#  19                          NaN                        22.72 %
#  20                          NaN                        23.81 %
#  21                          NaN                        24.17 %
#  22                          NaN                        24.34 %
#  23                       44.3 %                        24.68 %
#  24                       43.5 %                        24.99 %
#  25                       42.3 %                        25.83 %
#  26                       42.3 %                        26.14 %
#  27                       41.9 %                        26.18 %
#  28                       40.6 %                        26.20 %
#  29                       39.5 %                        26.21 %
#  30                       35.5 %                        26.25 %
#  31                       36.6 %                        27.42 %
#  32                       36.2 %                        28.26 %
#  33                       35.8 %                        28.39 %
#  34                       35.3 %                        28.58 %
#  35                       33.6 %                        28.89 %
#  36                       33.3 %                        29.65 %
#  37                       32.6 %                        30.51 %
#  38                       34.0 %                        31.23 %
#  39                        33.5%                        31.60 %  ,
#     Sectoral Shares of gross domestic product (GDP) of Bangladesh  \
#  0                                      A) Agriculture
#  1                            Agriculture and forestry
#  2                                Crops & horticulture
#  3                                     Animal Farmings
#  4                         Forest and related services
#  5                                             Fishing
#  6                                         B) Industry
#  7                                Mining and quarrying
#  8                     Natural gas and crude petroleum
#  9                                 Other mining & coal
#  10                                      Manufacturing
#  11                               Large & medium scale
#  12                                        Small scale
#  13                  Electricity, gas and water supply
#  14                                        Electricity
#  15                                                Gas
#  16                                              Water
#  17                                       Construction
#  18                                         C) Service
#  19  Wholesale and retail trade; repair of motor ve...
#  20                              Hotel and restaurants
#  21                 Transport, storage & communication
#  22                                     Land transport
#  23                                    Water transport
#  24                                      Air transport
#  25                Support transport services, storage
#  26                       Post and Tele communications
#  27                          Financial intermediations
#  28                    Monetary intermediation (banks)
#  29                                          Insurance
#  30                        Other financial auxiliaries
#  31       Real estate, renting and business activities
#  32                  Public administration and defence
#  33                                          Education
#  34                            Health and social works
#  35            Community, social and personal services
#  36  Percentage of sectoral shares of GDP of Bangla...
#
#                                            2015-16[66]  \
#  0                                               14.77
#  1                                               11.55
#  2                                                8.15
#  3                                                2.01
#  4                                                1.39
#  5                                                3.22
#  6                                               28.77
#  7                                                1.73
#  8                                                0.65
#  9                                                1.08
#  10                                              17.91
#  11                                              14.58
#  12                                               3.34
#  13                                               1.45
#  14                                               1.12
#  15                                               0.26
#  16                                               0.07
#  17                                               7.67
#  18                                              56.46
#  19                                              13.01
#  20                                               1.04
#  21                                              10.27
#  22                                               7.76
#  23                                               0.62
#  24                                               0.08
#  25                                               0.49
#  26                                               1.32
#  27                                               3.86
#  28                                               3.27
#  29                                               0.38
#  30                                               0.21
#  31                                               7.51
#  32                                               4.05
#  33                                               2.82
#  34                                               2.11
#  35                                              11.79
#  36  Percentage of sectoral shares of GDP of Bangla...
#
#                               2016-17[citation needed]  \
#  0                                               14.17
#  1                                               10.98
#  2                                                7.69
#  3                                                1.93
#  4                                                1.37
#  5                                                3.19
#  6                                               29.32
#  7                                                1.83
#  8                                                0.64
#  9                                                1.18
#  10                                              18.28
#  11                                              14.93
#  12                                               3.35
#  13                                                1.4
#  14                                               1.09
#  15                                               0.24
#  16                                               0.07
#  17                                               7.81
#  18                                               56.5
#  19                                              13.05
#  20                                               1.03
#  21                                                 10
#  22                                               7.64
#  23                                               0.59
#  24                                               0.07
#  25                                               0.47
#  26                                               1.24
#  27                                               3.91
#  28                                               3.34
#  29                                               0.36
#  30                                               0.21
#  31                                               7.73
#  32                                               4.19
#  33                                               3.04
#  34                                               2.08
#  35                                              11.46
#  36  Percentage of sectoral shares of GDP of Bangla...
#
#                               2017-18[citation needed]  \
#  0                                               13.82
#  1                                               10.68
#  2                                                7.48
#  3                                                1.86
#  4                                                1.34
#  5                                                3.14
#  6                                               30.17
#  7                                                1.83
#  8                                                0.62
#  9                                                 1.2
#  10                                              18.99
#  11                                              15.63
#  12                                               3.36
#  13                                               1.38
#  14                                               1.07
#  15                                               0.24
#  16                                               0.07
#  17                                               7.98
#  18                                                 56
#  19                                              13.15
#  20                                               1.04
#  21                                               9.61
#  22                                               7.38
#  23                                               0.55
#  24                                               0.07
#  25                                               0.46
#  26                                               1.16
#  27                                               3.93
#  28                                               3.37
#  29                                               0.34
#  30                                               0.22
#  31                                               7.82
#  32                                               4.24
#  33                                               3.03
#  34                                               2.07
#  35                                              11.11
#  36  Percentage of sectoral shares of GDP of Bangla...
#
#                               2018-19[citation needed]
#  0                                               13.32
#  1                                               10.25
#  2                                                7.12
#  3                                                1.79
#  4                                                1.35
#  5                                                3.07
#  6                                               31.15
#  7                                                1.82
#  8                                                0.58
#  9                                                1.24
#  10                                              19.89
#  11                                              16.37
#  12                                               3.52
#  13                                               1.33
#  14                                               1.04
#  15                                               0.22
#  16                                               0.07
#  17                                               8.12
#  18                                              55.53
#  19                                              13.34
#  20                                               1.04
#  21                                               9.34
#  22                                               7.22
#  23                                               0.51
#  24                                               0.07
#  25                                               0.44
#  26                                                1.1
#  27                                               3.89
#  28                                               3.35
#  29                                               0.34
#  30                                               0.21
#  31                                               7.87
#  32                                               4.09
#  33                                               3.02
#  34                                               2.15
#  35                                              10.78
#  36  Percentage of sectoral shares of GDP of Bangla...  ,
#      0                                                  1
#  0 NaN  This section contains content that is written ...,
#     Rank                              Company  \
#  0     1       Square Pharmaceuticals Limited
#  1     2  Dragon Sweater and Spinning Limited
#  2     3                   Ifad Autos Limited
#  3     4         Grameenphone Private Limited
#  4     5        Bangladesh Thai Aluminium Ltd
#  5     6                    City Bank Limited
#  6     7                       Golden Harvest
#  7     8                 IPDC Finance Limited
#  8     9           Olympic industries limited
#  9    10        Shahjalal Islami Bank Limited
#
#    Trading name at Dhaka Stock Exchange Headquarters            Industry  \
#  0                           SQURPHARMA        Dhaka     Pharmaceuticals
#  1                                 DSSL        Dhaka             Apparel
#  2                            IFADAUTOS        Dhaka          Automotive
#  3                                   GP        Dhaka  Telecommunications
#  4                               BDTHAI        Dhaka       Manufacturing
#  5                             CITYBANK        Dhaka             Banking
#  6                                GHAIL        Dhaka         Agriculture
#  7                                 IPDC        Dhaka  Financial Services
#  8                              OLYMPIC        Dhaka       Manufacturing
#  9                           SHAHJABANK        Dhaka             Banking
#
#     Trading Value
#  0        449.888
#  1        129.403
#  2        117.537
#  3        106.866
#  4         99.769
#  5         78.601
#  6         76.671
#  7         67.043
#  8         60.557
#  9         53.171  ,
#     Fiscal Year Total Export (in bn. US$) Total Import (in bn. US$)  \
#  0    2007–2008                    $14.11                    $25.21
#  1    2008–2009                    $15.56                    $22.51
#  2    2009–2010                     $16.7                    $23.83
#  3    2010–2011                    $22.93                      $32b
#  4    2011–2012                    $24.30                    $35.92
#  5    2012–2013                    $27.09                    $34.09
#  6    2013–2014                    $30.10                    $34.08
#  7    2014–2015                   $31.014                   $47.260
#  8    2015-2016                   $33.661                   $49.436
#  9    2016-2017                   $37.966                   $59.561
#  10   2017-2018                   $37.612                   $67.133
#  11   2018-2019                    $41.53                   $68.103
#
#     Foreign Remittance Earnings (in bn. US$)
#  0                                     $8.9b
#  1                                    $9.68b
#  2                                    $10.87
#  3                                    $11.65
#  4                                    $12.85
#  5                                     $14.4
#  6                                     $14.2
#  7                                    $14.23
#  8                                    $13.60
#  9                                    $12.76
#  10                                   $15.31
#  11                                   $14.98  ,
#     .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vteBangladesh articles  \
#  0                                             History
#  1   Timeline Outline Topics: Bengal Aviation Liter...
#  2   Ancient Vedic period Anga Vanga Pundra Suhma K...
#  3                                             Ancient
#  4                              Classical and Medieval
#  5                           Colonial and Pakistan era
#  6                                 Republic Bangladesh
#  7                                            Regional
#  8                                           Geography
#  9   Administrative: Divisions Districts Sub-distri...
#  10                                           Politics
#  11  Government Executive: President Prime Minister...
#  12                                         Government
#  13                           Military and Enforcement
#  14                                            Economy
#  15  Bangladesh Planning Commission Industries: Aut...
#  16                                            Society
#  17  Demographics Ethnic groups Bangladeshis Names ...
#  18                                       Demographics
#  19                                            Culture
#  20                                            Symbols
# ...
#  10  Government Executive: President Prime Minister...
#  11  Government Executive: President Prime Minister...
#  12  Executive: President Prime Minister Cabinet El...
#  13  Armed Forces: Army Navy Air Force Paramilitary...
#  14  Bangladesh Planning Commission Industries: Aut...
#  15  Bangladesh Planning Commission Industries: Aut...
#  16  Demographics Ethnic groups Bangladeshis Names ...
#  17  Demographics Ethnic groups Bangladeshis Names ...
#  18  Ethnic groups Bangladeshis Names Crime Educati...
#  19  Architecture Baul Bengalization Calendars Cine...
#  20  Amar Shonar Bangla Bangamata Bengal fire Benga...
#  21  .mw-parser-output .nobold{font-weight:normal}O...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ,
#                                                     0  \
#  0  Timeline Outline Topics: Bengal Aviation Liter...
#  1  Ancient Vedic period Anga Vanga Pundra Suhma K...
#  2                                            Ancient
#  3                             Classical and Medieval
#  4                          Colonial and Pakistan era
#  5                                Republic Bangladesh
#  6                                           Regional
#
#                                                     1
#  0  Timeline Outline Topics: Bengal Aviation Liter...
#  1  Ancient Vedic period Anga Vanga Pundra Suhma K...
#  2  Vedic period Anga Vanga Pundra Suhma Kingdom M...
#  3  Classical Empires: Pala Kamboja Sena Sultanate...
#  4  Portuguese Bengala British Bengal: Famine of 1...
#  5  Famine of 1974 Military coups 1975 1981 1982 1...
#  6  Chittagong Dhaka Jessore Noakhali Rangpur Sand...  ,
#                             0  \
#  0                    Ancient
#  1     Classical and Medieval
#  2  Colonial and Pakistan era
#  3        Republic Bangladesh
#  4                   Regional
#
#                                                     1
#  0  Vedic period Anga Vanga Pundra Suhma Kingdom M...
#  1  Classical Empires: Pala Kamboja Sena Sultanate...
#  2  Portuguese Bengala British Bengal: Famine of 1...
#  3  Famine of 1974 Military coups 1975 1981 1982 1...
#  4  Chittagong Dhaka Jessore Noakhali Rangpur Sand...  ,
#                                                     0  \
#  0  Administrative: Divisions Districts Sub-distri...
#
#                                                     1
#  0  Administrative: Divisions Districts Sub-distri...  ,
#                                                     0  \
#  0  Government Executive: President Prime Minister...
#  1                                         Government
#  2                           Military and Enforcement
#
#                                                     1
#  0  Government Executive: President Prime Minister...
#  1  Executive: President Prime Minister Cabinet El...
#  2  Armed Forces: Army Navy Air Force Paramilitary...  ,
#                            0                                                  1
#  0                Government  Executive: President Prime Minister Cabinet El...
#  1  Military and Enforcement  Armed Forces: Army Navy Air Force Paramilitary...,
#                                                     0  \
#  0  Bangladesh Planning Commission Industries: Aut...
#
#                                                     1
#  0  Bangladesh Planning Commission Industries: Aut...  ,
#                                                     0  \
#  0  Demographics Ethnic groups Bangladeshis Names ...
#  1                                       Demographics
#  2                                            Culture
#  3                                            Symbols
#
#                                                     1
#  0  Demographics Ethnic groups Bangladeshis Names ...
#  1  Ethnic groups Bangladeshis Names Crime Educati...
#  2  Architecture Baul Bengalization Calendars Cine...
#  3  Amar Shonar Bangla Bangamata Bengal fire Benga...  ,
#                0                                                  1
#  0  Demographics  Ethnic groups Bangladeshis Names Crime Educati...
#  1       Culture  Architecture Baul Bengalization Calendars Cine...
#  2       Symbols  Amar Shonar Bangla Bangamata Bengal fire Benga...,
#    vteSouth Asian Free Trade Area (SAFTA)  \
#  0                                Members
#
#              vteSouth Asian Free Trade Area (SAFTA).1  \
#  0  Afghanistan  Bangladesh  Bhutan  India  Maldiv...
#
#     vteSouth Asian Free Trade Area (SAFTA).2
#  0                                       NaN  ,
#                           vteWorld Trade Organization  \
#  0                                             System
#  1                                             Issues
#  2                                         Agreements
#  3                             MinisterialConferences
#  4                                             People
#  5                                            Members
#  6                                     European Union
#  7  Special administrative regions of the People's...
#
#                         vteWorld Trade Organization.1
#  0  Accession and membership Appellate Body Disput...
#  1  Criticism Doha Development Round Singapore iss...
#  2  General Agreement on Tariffs and Trade Agricul...
#  3  1st (1996) 2nd (1998) 3rd (1999) 4th (2001) 5t...
#  4  Ngozi Okonjo-Iweala (Director-General) Roberto...
#  5  Afghanistan Albania Algeria Angola Antigua and...
#  6  Austria Belgium Bulgaria Croatia Cyprus Czech ...
#  7  Special administrative regions of the People's...  ,
#                  0                                                  1
#  0  European Union  Austria Belgium Bulgaria Croatia Cyprus Czech ...,
#                    vteEconomy of Asia  \
#  0                   Sovereign states
#  1     States withlimited recognition
#  2  Dependencies andother territories
#  3              Category  Asia portal
#
#                                  vteEconomy of Asia.1
#  0  Afghanistan Armenia Azerbaijan Bahrain Banglad...
#  1  Abkhazia Artsakh Northern Cyprus Palestine Sou...
#  2  British Indian Ocean Territory Christmas Islan...
#  3                              Category  Asia portal  ,
#               vteUrbanisation in Asia  \
#  0                   Sovereign states
#  1     States withlimited recognition
#  2  Dependencies andother territories
#  3              Category  Asia portal
#
#                             vteUrbanisation in Asia.1
#  0  Afghanistan Armenia Azerbaijan Bahrain Banglad...
#  1  Abkhazia Artsakh Northern Cyprus Palestine Sou...
#  2  British Indian Ocean Territory Christmas Islan...
#  3                              Category  Asia portal  ]

# %%
#Question 1. Find any other HTML data table online that potentially can be useful for 
#your assignments project. Read it using read_html() function and apply appropriate 
#cleaning.
print(f'Total tables: {len(table_bd)}')
# Out:
# Total tables: 21

# %%
#Question 1. Find any other HTML data table online that potentially can be useful for 
#your assignments project. Read it using read_html() function and apply appropriate 
#cleaning.
table_bd[2]
# Out:
#     Year  GDP(in bn. US$ PPP)  GDP per capita(in US$ PPP) GDP growth(real)  \
# 0   1980                 41.2                         500            3.1 %
# 1   1981                 47.4                         560            5.6 %
# 2   1982                 52.0                         597            3.2 %
# 3   1983                 56.5                         633            4.6 %
# 4   1984                 61.0                         664            4.2 %
# 5   1985                 65.3                         693            3.7 %
# 6   1986                 69.3                         715            4.0 %
# 7   1987                 73.1                         735            2.9 %
# 8   1988                 77.5                         759            2.4 %
# 9   1989                 84.0                         801            4.3 %
# 10  1990                 91.1                         848            4.6 %
# 11  1991                 98.1                         892            4.2 %
# 12  1992                105.1                         935            4.8 %
# 13  1993                112.3                         977            4.3 %
# 14  1994                119.9                        1021            4.5 %
# 15  1995                128.2                        1069            4.8 %
# 16  1996                137.1                        1120            5.0 %
# 17  1997                146.8                        1175            5.3 %
# 18  1998                155.9                        1223            5.0 %
# 19  1999                166.9                        1284            5.4 %
# 20  2000                180.2                        1361            5.6 %
# 21  2001                193.2                        1434            4.8 %
# 22  2002                205.7                        1501            4.8 %
# 23  2003                221.9                        1594            5.8 %
# 24  2004                241.9                        1713            6.1 %
# 25  2005                265.5                        1855            6.3 %
# 26  2006                292.4                        2018            6.9 %
# 27  2007                319.7                        2183            6.5 %
# 28  2008                344.0                        2325            5.5 %
# 29  2009                365.0                        2441            5.3 %
# 30  2010                391.7                        2592            6.0 %
# 31  2011                425.8                        2785            6.5 %
# 32  2012                460.8                        2979            6.3 %
# 33  2013                496.5                        3171            6.0 %
# 34  2014                537.3                        3396            6.3 %
# 35  2015                581.6                        3638            6.8 %
# 36  2016                629.9                        3900            7.2 %
# 37  2017                710.5                        4331            7.6 %
# 38  2018                785.9                        4730            7.9 %
# 39  2019                869.4                        5228             8.1%
#
#    Inflation rate(in Percent) Unemployment Rate (in Percent)  \
# 0                      15.4 %                            NaN
# 1                      14.5 %                            NaN
# 2                      12.9 %                            NaN
# 3                       9.5 %                            NaN
# 4                      10.4 %                            NaN
# 5                      10.5 %                            NaN
# 6                      10.2 %                            NaN
# 7                      10.8 %                            NaN
# 8                       9.7 %                            NaN
# 9                       8.7 %                            NaN
# 10                     10.5 %                            NaN
# 11                      8.3 %                         2.20 %
# 12                      3.6 %                         2.25 %
# 13                      3.0 %                         2.37 %
# 14                      6.2 %                         2.44 %
# 15                     10.1 %                         2.48 %
# 16                      2.5 %                         2.51 %
# 17                      5.0 %                         2.69 %
# 18                      8.6 %                         2.83 %
# 19                      6.2 %                         3.10 %
# 20                      2.5 %                         3.27 %
# 21                      1.9 %                         3.55 %
# 22                      3.7 %                         3.96 %
# 23                      5.4 %                         4.32 %
# 24                      6.1 %                         4.30 %
# 25                      7.0 %                         4.25 %
# 26                      6.8 %                         3.59 %
# 27                      9.1 %                         3.77 %
# 28                      8.9 %                         4.07 %
# 29                      4.9 %                         5.00 %
# 30                      9.4 %                         3.37 %
# 31                     11.5 %                         3.71 %
# 32                      6.2 %                         4.04 %
# 33                      7.5 %                         4.43 %
# 34                      7.0 %                         4.41 %
# 35                      6.2 %                         4.42 %
# 36                      5.7 %                         4.35 %
# 37                      5.6 %                         4.37 %
# 38                      5.6 %                         4.30 %
# 39                       5.5%                         4.29 %
#
#    Government debt(in % of GDP) Total Investment (in % of GDP)
# 0                           NaN                        14.44 %
# 1                           NaN                        17.16 %
# 2                           NaN                         17.36%
# 3                           NaN                        16.56 %
# 4                           NaN                        16.48 %
# 5                           NaN                        15.83 %
# 6                           NaN                        16.18 %
# 7                           NaN                        15.47 %
# 8                           NaN                        15.74 %
# 9                           NaN                        16.12 %
# 10                          NaN                        16.46 %
# 11                          NaN                        16.90 %
# 12                          NaN                        17.31 %
# 13                          NaN                        17.95 %
# 14                          NaN                        18.40 %
# 15                          NaN                        19.12 %
# 16                          NaN                        20.73 %
# 17                          NaN                        21.82 %
# 18                          NaN                        22.12 %
# 19                          NaN                        22.72 %
# 20                          NaN                        23.81 %
# 21                          NaN                        24.17 %
# 22                          NaN                        24.34 %
# 23                       44.3 %                        24.68 %
# 24                       43.5 %                        24.99 %
# 25                       42.3 %                        25.83 %
# 26                       42.3 %                        26.14 %
# 27                       41.9 %                        26.18 %
# 28                       40.6 %                        26.20 %
# 29                       39.5 %                        26.21 %
# 30                       35.5 %                        26.25 %
# 31                       36.6 %                        27.42 %
# 32                       36.2 %                        28.26 %
# 33                       35.8 %                        28.39 %
# 34                       35.3 %                        28.58 %
# 35                       33.6 %                        28.89 %
# 36                       33.3 %                        29.65 %
# 37                       32.6 %                        30.51 %
# 38                       34.0 %                        31.23 %
# 39                        33.5%                        31.60 %

# %%
#Question 1. Find any other HTML data table online that potentially can be useful for 
#your assignments project. Read it using read_html() function and apply appropriate 
#cleaning.
len(table_bd)
# Out:
# 21

# %%
#Question 1. Find any other HTML data table online that potentially can be useful for 
#your assignments project. Read it using read_html() function and apply appropriate 
#cleaning.
df = table_bd[2]
df.head(10)
# Out:
#    Year  GDP(in bn. US$ PPP)  GDP per capita(in US$ PPP) GDP growth(real)  \
# 0  1980                 41.2                         500            3.1 %
# 1  1981                 47.4                         560            5.6 %
# 2  1982                 52.0                         597            3.2 %
# 3  1983                 56.5                         633            4.6 %
# 4  1984                 61.0                         664            4.2 %
# 5  1985                 65.3                         693            3.7 %
# 6  1986                 69.3                         715            4.0 %
# 7  1987                 73.1                         735            2.9 %
# 8  1988                 77.5                         759            2.4 %
# 9  1989                 84.0                         801            4.3 %
#
#   Inflation rate(in Percent) Unemployment Rate (in Percent)  \
# 0                     15.4 %                            NaN
# 1                     14.5 %                            NaN
# 2                     12.9 %                            NaN
# 3                      9.5 %                            NaN
# 4                     10.4 %                            NaN
# 5                     10.5 %                            NaN
# 6                     10.2 %                            NaN
# 7                     10.8 %                            NaN
# 8                      9.7 %                            NaN
# 9                      8.7 %                            NaN
#
#   Government debt(in % of GDP) Total Investment (in % of GDP)
# 0                          NaN                        14.44 %
# 1                          NaN                        17.16 %
# 2                          NaN                         17.36%
# 3                          NaN                        16.56 %
# 4                          NaN                        16.48 %
# 5                          NaN                        15.83 %
# 6                          NaN                        16.18 %
# 7                          NaN                        15.47 %
# 8                          NaN                        15.74 %
# 9                          NaN                        16.12 %

# %%
#Question 1. Find any other HTML data table online that potentially can be useful for 
#your assignments project. Read it using read_html() function and apply appropriate 
#cleaning.
df.columns
# Out:
# Index(['Year', 'GDP(in bn. US$ PPP)', 'GDP per capita(in US$ PPP)',
#        'GDP growth(real)', 'Inflation rate(in Percent)',
#        'Unemployment Rate (in Percent)', 'Government debt(in % of GDP)',
#        'Total Investment (in % of GDP)'],
#       dtype='object')

# %%
#Question 1. Find any other HTML data table online that potentially can be useful for 
#your assignments project. Read it using read_html() function and apply appropriate 
#cleaning.
#changing value from integer to float, first replace the integer with nothing
#df['GDP per capita(in US$ PPP)'].replace({'%':''}, regex=True).astype('float')
df=df.replace({'%':''},regex=True)

# %%
#Question 1. Find any other HTML data table online that potentially can be useful for 
#your assignments project. Read it using read_html() function and apply appropriate 
#cleaning.
df.head(10)
# Out:
#    Year  GDP(in bn. US$ PPP)  GDP per capita(in US$ PPP) GDP growth(real)  \
# 0  1980                 41.2                         500             3.1
# 1  1981                 47.4                         560             5.6
# 2  1982                 52.0                         597             3.2
# 3  1983                 56.5                         633             4.6
# 4  1984                 61.0                         664             4.2
# 5  1985                 65.3                         693             3.7
# 6  1986                 69.3                         715             4.0
# 7  1987                 73.1                         735             2.9
# 8  1988                 77.5                         759             2.4
# 9  1989                 84.0                         801             4.3
#
#   Inflation rate(in Percent) Unemployment Rate (in Percent)  \
# 0                      15.4                             NaN
# 1                      14.5                             NaN
# 2                      12.9                             NaN
# 3                       9.5                             NaN
# 4                      10.4                             NaN
# 5                      10.5                             NaN
# 6                      10.2                             NaN
# 7                      10.8                             NaN
# 8                       9.7                             NaN
# 9                       8.7                             NaN
#
#   Government debt(in % of GDP) Total Investment (in % of GDP)
# 0                          NaN                         14.44
# 1                          NaN                         17.16
# 2                          NaN                          17.36
# 3                          NaN                         16.56
# 4                          NaN                         16.48
# 5                          NaN                         15.83
# 6                          NaN                         16.18
# 7                          NaN                         15.47
# 8                          NaN                         15.74
# 9                          NaN                         16.12

# %%
#Question 1. Find any other HTML data table online that potentially can be useful for 
#your assignments project. Read it using read_html() function and apply appropriate 
#cleaning.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Year                            40 non-null     int64
#  1   GDP(in bn. US$ PPP)             40 non-null     float64
#  2   GDP per capita(in US$ PPP)      40 non-null     int64
#  3   GDP growth(real)                40 non-null     object
#  4   Inflation rate(in Percent)      40 non-null     object
#  5   Unemployment Rate (in Percent)  29 non-null     object
#  6   Government debt(in % of GDP)    17 non-null     object
#  7   Total Investment (in % of GDP)  40 non-null     object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 2.6+ KB

# %%
#Question 1. Find any other HTML data table online that potentially can be useful for 
#your assignments project. Read it using read_html() function and apply appropriate 
#cleaning.
#strip removes extra spaces
from unicodedata import normalize
def clean_normalize_whitespace(x):
    if isinstance(x, str):
        return normalize('NFKC', x).strip()
    else:
        return x

# %%
#Question 1. Find any other HTML data table online that potentially can be useful for 
#your assignments project. Read it using read_html() function and apply appropriate 
#cleaning.
df = df.applymap(clean_normalize_whitespace)

# %%
#Question 1. Find any other HTML data table online that potentially can be useful for 
#your assignments project. Read it using read_html() function and apply appropriate 
#cleaning.
df
# Out:
#     Year  GDP(in bn. US$ PPP)  GDP per capita(in US$ PPP) GDP growth(real)  \
# 0   1980                 41.2                         500              3.1
# 1   1981                 47.4                         560              5.6
# 2   1982                 52.0                         597              3.2
# 3   1983                 56.5                         633              4.6
# 4   1984                 61.0                         664              4.2
# 5   1985                 65.3                         693              3.7
# 6   1986                 69.3                         715              4.0
# 7   1987                 73.1                         735              2.9
# 8   1988                 77.5                         759              2.4
# 9   1989                 84.0                         801              4.3
# 10  1990                 91.1                         848              4.6
# 11  1991                 98.1                         892              4.2
# 12  1992                105.1                         935              4.8
# 13  1993                112.3                         977              4.3
# 14  1994                119.9                        1021              4.5
# 15  1995                128.2                        1069              4.8
# 16  1996                137.1                        1120              5.0
# 17  1997                146.8                        1175              5.3
# 18  1998                155.9                        1223              5.0
# 19  1999                166.9                        1284              5.4
# 20  2000                180.2                        1361              5.6
# 21  2001                193.2                        1434              4.8
# 22  2002                205.7                        1501              4.8
# 23  2003                221.9                        1594              5.8
# 24  2004                241.9                        1713              6.1
# 25  2005                265.5                        1855              6.3
# 26  2006                292.4                        2018              6.9
# 27  2007                319.7                        2183              6.5
# 28  2008                344.0                        2325              5.5
# 29  2009                365.0                        2441              5.3
# 30  2010                391.7                        2592              6.0
# 31  2011                425.8                        2785              6.5
# 32  2012                460.8                        2979              6.3
# 33  2013                496.5                        3171              6.0
# 34  2014                537.3                        3396              6.3
# 35  2015                581.6                        3638              6.8
# 36  2016                629.9                        3900              7.2
# 37  2017                710.5                        4331              7.6
# 38  2018                785.9                        4730              7.9
# 39  2019                869.4                        5228              8.1
#
#    Inflation rate(in Percent) Unemployment Rate (in Percent)  \
# 0                        15.4                            NaN
# 1                        14.5                            NaN
# 2                        12.9                            NaN
# 3                         9.5                            NaN
# 4                        10.4                            NaN
# 5                        10.5                            NaN
# 6                        10.2                            NaN
# 7                        10.8                            NaN
# 8                         9.7                            NaN
# 9                         8.7                            NaN
# 10                       10.5                            NaN
# 11                        8.3                           2.20
# 12                        3.6                           2.25
# 13                        3.0                           2.37
# 14                        6.2                           2.44
# 15                       10.1                           2.48
# 16                        2.5                           2.51
# 17                        5.0                           2.69
# 18                        8.6                           2.83
# 19                        6.2                           3.10
# 20                        2.5                           3.27
# 21                        1.9                           3.55
# 22                        3.7                           3.96
# 23                        5.4                           4.32
# 24                        6.1                           4.30
# 25                        7.0                           4.25
# 26                        6.8                           3.59
# 27                        9.1                           3.77
# 28                        8.9                           4.07
# 29                        4.9                           5.00
# 30                        9.4                           3.37
# 31                       11.5                           3.71
# 32                        6.2                           4.04
# 33                        7.5                           4.43
# 34                        7.0                           4.41
# 35                        6.2                           4.42
# 36                        5.7                           4.35
# 37                        5.6                           4.37
# 38                        5.6                           4.30
# 39                        5.5                           4.29
#
#    Government debt(in % of GDP) Total Investment (in % of GDP)
# 0                           NaN                          14.44
# 1                           NaN                          17.16
# 2                           NaN                          17.36
# 3                           NaN                          16.56
# 4                           NaN                          16.48
# 5                           NaN                          15.83
# 6                           NaN                          16.18
# 7                           NaN                          15.47
# 8                           NaN                          15.74
# 9                           NaN                          16.12
# 10                          NaN                          16.46
# 11                          NaN                          16.90
# 12                          NaN                          17.31
# 13                          NaN                          17.95
# 14                          NaN                          18.40
# 15                          NaN                          19.12
# 16                          NaN                          20.73
# 17                          NaN                          21.82
# 18                          NaN                          22.12
# 19                          NaN                          22.72
# 20                          NaN                          23.81
# 21                          NaN                          24.17
# 22                          NaN                          24.34
# 23                         44.3                          24.68
# 24                         43.5                          24.99
# 25                         42.3                          25.83
# 26                         42.3                          26.14
# 27                         41.9                          26.18
# 28                         40.6                          26.20
# 29                         39.5                          26.21
# 30                         35.5                          26.25
# 31                         36.6                          27.42
# 32                         36.2                          28.26
# 33                         35.8                          28.39
# 34                         35.3                          28.58
# 35                         33.6                          28.89
# 36                         33.3                          29.65
# 37                         32.6                          30.51
# 38                         34.0                          31.23
# 39                         33.5                          31.60

# %%
#Question 1. Find any other HTML data table online that potentially can be useful for 
#your assignments project. Read it using read_html() function and apply appropriate 
#cleaning.
df.columns = df.columns.to_series().apply(clean_normalize_whitespace)
df.columns
# Out:
# Index(['Year', 'GDP(in bn. US$ PPP)', 'GDP per capita(in US$ PPP)',
#        'GDP growth(real)', 'Inflation rate(in Percent)',
#        'Unemployment Rate (in Percent)', 'Government debt(in % of GDP)',
#        'Total Investment (in % of GDP)'],
#       dtype='object')

# %%
#Question 1. Find any other HTML data table online that potentially can be useful for 
#your assignments project. Read it using read_html() function and apply appropriate 
#cleaning.
#if your data have any character
df['Year'].replace({'%': '', '−': '-', '\(est\)': ''}, regex=True).astype('int')
# Out:
# 0     1980
# 1     1981
# 2     1982
# 3     1983
# 4     1984
# 5     1985
# 6     1986
# 7     1987
# 8     1988
# 9     1989
# 10    1990
# 11    1991
# 12    1992
# 13    1993
# 14    1994
# 15    1995
# 16    1996
# 17    1997
# 18    1998
# 19    1999
# 20    2000
# 21    2001
# 22    2002
# 23    2003
# 24    2004
# 25    2005
# 26    2006
# 27    2007
# 28    2008
# 29    2009
# 30    2010
# 31    2011
# 32    2012
# 33    2013
# 34    2014
# 35    2015
# 36    2016
# 37    2017
# 38    2018
# 39    2019
# Name: Year, dtype: int32

# %%
#Question 1. Find any other HTML data table online that potentially can be useful for 
#your assignments project. Read it using read_html() function and apply appropriate 
#cleaning.
clean_dict = {'%': '', '−': '-', '\(est\)': ''}

# %%
df1 = df.dropna(axis=1)
print(df1)
# Out:
#     Year  GDP(in bn. US$ PPP)  GDP per capita(in US$ PPP) GDP growth(real)  \
# 0   1980                 41.2                         500              3.1
# 1   1981                 47.4                         560              5.6
# 2   1982                 52.0                         597              3.2
# 3   1983                 56.5                         633              4.6
# 4   1984                 61.0                         664              4.2
# 5   1985                 65.3                         693              3.7
# 6   1986                 69.3                         715              4.0
# 7   1987                 73.1                         735              2.9
# 8   1988                 77.5                         759              2.4
# 9   1989                 84.0                         801              4.3
# 10  1990                 91.1                         848              4.6
# 11  1991                 98.1                         892              4.2
# 12  1992                105.1                         935              4.8
# 13  1993                112.3                         977              4.3
# 14  1994                119.9                        1021              4.5
# 15  1995                128.2                        1069              4.8
# 16  1996                137.1                        1120              5.0
# 17  1997                146.8                        1175              5.3
# 18  1998                155.9                        1223              5.0
# 19  1999                166.9                        1284              5.4
# 20  2000                180.2                        1361              5.6
# 21  2001                193.2                        1434              4.8
# 22  2002                205.7                        1501              4.8
# 23  2003                221.9                        1594              5.8
# 24  2004                241.9                        1713              6.1
# 25  2005                265.5                        1855              6.3
# 26  2006                292.4                        2018              6.9
# 27  2007                319.7                        2183              6.5
# 28  2008                344.0                        2325              5.5
# 29  2009                365.0                        2441              5.3
# 30  2010                391.7                        2592              6.0
# 31  2011                425.8                        2785              6.5
# 32  2012                460.8                        2979              6.3
# 33  2013                496.5                        3171              6.0
# 34  2014                537.3                        3396              6.3
# 35  2015                581.6                        3638              6.8
# 36  2016                629.9                        3900              7.2
# 37  2017                710.5                        4331              7.6
# 38  2018                785.9                        4730              7.9
# 39  2019                869.4                        5228              8.1
#
#    Inflation rate(in Percent) Total Investment (in % of GDP)
# 0                        15.4                          14.44
# 1                        14.5                          17.16
# 2                        12.9                          17.36
# 3                         9.5                          16.56
# 4                        10.4                          16.48
# 5                        10.5                          15.83
# 6                        10.2                          16.18
# 7                        10.8                          15.47
# 8                         9.7                          15.74
# 9                         8.7                          16.12
# 10                       10.5                          16.46
# 11                        8.3                          16.90
# 12                        3.6                          17.31
# 13                        3.0                          17.95
# 14                        6.2                          18.40
# 15                       10.1                          19.12
# 16                        2.5                          20.73
# 17                        5.0                          21.82
# 18                        8.6                          22.12
# 19                        6.2                          22.72
# 20                        2.5                          23.81
# 21                        1.9                          24.17
# 22                        3.7                          24.34
# 23                        5.4                          24.68
# 24                        6.1                          24.99
# 25                        7.0                          25.83
# 26                        6.8                          26.14
# 27                        9.1                          26.18
# 28                        8.9                          26.20
# 29                        4.9                          26.21
# 30                        9.4                          26.25
# 31                       11.5                          27.42
# 32                        6.2                          28.26
# 33                        7.5                          28.39
# 34                        7.0                          28.58
# 35                        6.2                          28.89
# 36                        5.7                          29.65
# 37                        5.6                          30.51
# 38                        5.6                          31.23
# 39                        5.5                          31.60

# %%
#Question 1. Find any other HTML data table online that potentially can be useful for 
#your assignments project. Read it using read_html() function and apply appropriate 
#cleaning.
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 6 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Year                            40 non-null     int64
#  1   GDP(in bn. US$ PPP)             40 non-null     float64
#  2   GDP per capita(in US$ PPP)      40 non-null     int64
#  3   GDP growth(real)                40 non-null     object
#  4   Inflation rate(in Percent)      40 non-null     object
#  5   Total Investment (in % of GDP)  40 non-null     object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 2.0+ KB

# %%
#Question 2. Implement an example of data retrieval using one of the packages listed 
#in the table.
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
import pandas as pd
import numpy as np
import re
import csv

# %%
#Question 2. Implement an example of data retrieval using one of the packages listed 
#in the table.
bearer_tocken = 'AAAAAAAAAAAAAAAAAAAAAIQnVgEAAAAAG3oZJnERuECSPzZXlklkx8FRXNc%3DxxELnZXj9Nwww6XSzy5hHAzCvE8EpGQiSvSZaXMSTY2unJQ6VM'
client = tweepy.Client(bearer_tocken)
path = 'C:/DIT45602/lectures/'
screen_name = 'iamsrk'

# %%
#Question 2. Implement an example of data retrieval using one of the packages listed 
#in the table.
tweets = client.get_users_tweets(client.get_user(username=screen_name).data['id'])
outtweets = [[tweet.id, tweet.text] for tweet in tweets.data]

with open(path + '%s_tweets.csv' % screen_name, 'w', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(["id","text"])
        writer.writerows(outtweets)
        print('saved - ' + path  )
pass
# Out:
# saved - C:/DIT45602/lectures/

# %%
#Question 2. Implement an example of data retrieval using one of the packages listed 
#in the table.
# Printing tweets of Prime Minister of Bangladesh Sheikh Hasina form her Twitter profile
def remove_pattern(text,pattern):
    
    # re.findall() finds the pattern i.e @user and puts it in a list for further task
    r = re.findall(pattern,text)
    
    # re.sub() removes @user from the sentences in the dataset
    for i in r:
        text = re.sub(i,"",text)
    
    return text

# %%
#Question 2. Implement an example of data retrieval using one of the packages listed 
#in the table.
## Suppose we have a text with many email addresses
str = 'purple alice@google.com, blah monkey bob@abc.com blah dishwasher'

## Here re.findall() returns a list of all the found email strings
emails = re.findall(r'[\w\.-]+@[\w\.-]+', str) ## ['alice@google.com', 'bob@abc.com']
for email in emails:
    # do something with each found email string
    print(email)
# Out:
# alice@google.com
# bob@abc.com

# %%
#Question 2. Implement an example of data retrieval using one of the packages listed 
#in the table.
# Printing tweets of Prime Minister of Bangladesh Sheikh Hasina form her Twitter profile
raw_tweets = pd.read_csv('C:/DIT45602/lectures/'+screen_name+'_tweets.csv')
raw_tweets
# Out:
#                     id                                               text
# 0  1503604476934242308  Kuch kuch hone wala hai, OTT ki duniya mein. h...
# 1  1499700448005337089  Extremely happy to see  #LoveHostel receiving ...
# 2  1499011302806605826  Ok boys and girls time to get back to work. Ha...
# 3  1499010940058345475  If I knew you were coming home would have told...
# 4  1499010607403524104  Aaj kal toh Thums Up hi pi raha hoon….maybe it...
# 5  1499010039322853376  Toh aadha reply….kar….ok #Pathaan https://t.co...
# 6  1499009660505911302  Dimaag try kar shaayad work karega…Mann pyaar ...
# 7  1499009443773616128  Thoda tum adjust kar lena thoda main kar dunga...
# 8  1499009111400144896  Arre yaar Aamir kehta hai pehle Pathaan dikha!...
# 9  1499008466035167234  Ok next time I will be ‘Khabardaar’ #Pathaan h...

# %%
#Question 3: Add legend to the plot with caption for all lines on the plot.
#Graph-1
#Comment-In this plot which colors represent which data comes automatically.
#I addeed title in the graph.
plt.style.use('seaborn-whitegrid')
df_GDP.plot.line(x='Year', y=['Inflation rate (in Percent)', 'Unemployment (in Percent)'])
plt.title('Changes of Employment with Inflation')
# Out:
# Text(0.5, 1.0, 'Changes of Employment with Inflation')

# %%
#Question 3: Add legend to the plot with caption for all lines on the plot.
#Graph-2
norm_data = pd.DataFrame(np.random.normal(size=100000))
norm_data.plot(kind="density",
 figsize=(10,10));
arr1 = plt.vlines(norm_data.mean(), # Plot green line at mean
 ymin=0,
 ymax=0.4,
 linewidth=5.0,
 color="green");
arr2 = plt.vlines(norm_data.median(), # Plot red line at median
 ymin=0,
 ymax=0.4,
 linewidth=2.0,
 color="red");
plt.legend([arr1, arr2], ['mean','median'],bbox_to_anchor=(1.0, 1),loc='upper left')
plt.title('Descriptive statistics of Random Generated Dataset')
plt.show()

# %%
#Question 3: Add legend to the plot with caption for all lines on the plot.
#Graph-3

skewed_data = pd.DataFrame(np.random.exponential(size=100000))
skewed_data.plot(kind="density",
 figsize=(10,10),
 xlim=(-1,5));
arr1 = plt.vlines(skewed_data.mean(), # Plot yellow line at mean
 ymin=0,
 ymax=0.8,
 linewidth=5.0,
 color="yellow");
arr2 = plt.vlines(skewed_data.median(), # Plot red line at median
 ymin=0,
 ymax=0.8,
 linewidth=2.0,
 color="red");
plt.legend([arr1, arr2], ['mean','median'],bbox_to_anchor=(1.0, 1),loc='upper left')
plt.title('Descriptive statistics of Random Generated skewed_data')
plt.show()

# %%
#Question 3: Add legend to the plot with caption for all lines on the plot.
#Graph-4
norm_data = np.random.normal(size=50)
outliers = np.random.normal(15, size=3)
combined_data = pd.DataFrame(np.concatenate((norm_data, outliers), axis=0))
combined_data.plot(kind="density",
 figsize=(10,10),
 xlim=(-5,20));
arr1 = plt.vlines(combined_data.mean(), # Plot black line at mean
 ymin=0,
 ymax=0.2,
 linewidth=5.0,
 color="black");
arr2 = plt.vlines(combined_data.median(), # Plot red line at median
 ymin=0,
 ymax=0.2,
 linewidth=2.0,
 color="red");
plt.legend([arr1, arr2], ['mean','median'],bbox_to_anchor=(1.0, 1),loc='upper left')
plt.title('Descriptive statistics of Random Generated norm_data')
plt.show()

# %%
#Question 3: Add legend to the plot with caption for all lines on the plot.
#Graph-4(Box plot)
mtcars.boxplot(column="mpg",
 return_type='axes',
 figsize=(8,8)
)
plt.title('Box Plot of mpg column of mtcars Dataset')
plt.legend(bbox_to_anchor=(1.0, 1),loc='upper right', title='max - 33.9\nmin - 10.4\nQ1 - 15.42%\nQ2 - 19.20%\nQ3 - 22.80%')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#Question 3: Add legend to the plot with caption for all lines on the plot.
#Graph-5
#Comment-In this plot which colors represent which data comes automatically.
#I addeed title in the graph.
norm_data = np.random.normal(size=100000)
skewed_data = np.concatenate((np.random.normal(size=35000)+2,
 np.random.exponential(size=65000)),
axis=0)
uniform_data = np.random.uniform(0,2, size=100000)
peaked_data = np.concatenate((np.random.exponential(size=50000),
 np.random.exponential(size=50000)*(-1)),
axis=0)
data_df = pd.DataFrame({"norm":norm_data,
 "skewed":skewed_data,
"uniform":uniform_data,
"peaked":peaked_data})
data_df.plot(kind="density",
 figsize=(10,10),
 xlim=(-5,5));
plt.title('Plot of Random Generated Exponential Data')
plt.show()

# %%
#Question 4: Plot boxplots for all numerical columns in the dataset and provide your 
#comments on what you observe.
mtcars
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# Merc 450SE           16.4    8  275.8  180  3.07  4.070  17.40   0   0     3
# Merc 450SL           17.3    8  275.8  180  3.07  3.730  17.60   0   0     3
# Merc 450SLC          15.2    8  275.8  180  3.07  3.780  18.00   0   0     3
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3
# Chrysler Imperial    14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Fiat 128             32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# Honda Civic          30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# Toyota Corolla       33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# Toyota Corona        21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# Dodge Challenger     15.5    8  318.0  150  2.76  3.520  16.87   0   0     3
# AMC Javelin          15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Camaro Z28           13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Pontiac Firebird     19.2    8  400.0  175  3.08  3.845  17.05   0   0     3
# Fiat X1-9            27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# Porsche 914-2        26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# Lotus Europa         30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# Ford Pantera L       15.8    8  351.0  264  4.22  3.170  14.50   0   1     5
# Ferrari Dino         19.7    6  145.0  175  3.62  2.770  15.50   0   1     5
# Maserati Bora        15.0    8  301.0  335  3.54  3.570  14.60   0   1     5
# Volvo 142E           21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
#
#                      carb
# model
# Mazda RX4               4
# Mazda RX4 Wag           4
# Datsun 710              1
# Hornet 4 Drive          1
# Hornet Sportabout       2
# Valiant                 1
# Duster 360              4
# Merc 240D               2
# Merc 230                2
# Merc 280                4
# Merc 280C               4
# Merc 450SE              3
# Merc 450SL              3
# Merc 450SLC             3
# Cadillac Fleetwood      4
# Lincoln Continental     4
# Chrysler Imperial       4
# Fiat 128                1
# Honda Civic             2
# Toyota Corolla          1
# Toyota Corona           1
# Dodge Challenger        2
# AMC Javelin             2
# Camaro Z28              4
# Pontiac Firebird        2
# Fiat X1-9               1
# Porsche 914-2           2
# Lotus Europa            2
# Ford Pantera L          4
# Ferrari Dino            6
# Maserati Bora           8
# Volvo 142E              2

# %%
#Question 4: Plot boxplots for all numerical columns in the dataset and provide your 
#comments on what you observe.
mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# 25%    16.892500   0.000000   0.000000   3.000000   2.0000
# 50%    17.710000   0.000000   0.000000   4.000000   2.0000
# 75%    18.900000   1.000000   1.000000   4.000000   4.0000
# max    22.900000   1.000000   1.000000   5.000000   8.0000

# %%
#Question 4: Plot boxplots for all numerical columns in the dataset and provide your 
#comments on what you observe.
mtcars.median()
# Out:
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.710
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %%
#Question 4: Plot boxplots for all numerical columns in the dataset and provide your 
#comments on what you observe.
mtcars.boxplot(column="mpg",
 return_type='axes',
 figsize=(8,8)
)
plt.title('Box Plot of mpg column of mtcars Dataset')

#Comments on Box-plot
#A boxplot describes summary of five numbers of a dataset.
#These are minimum, first quartile, median, third quartile, and maximum numbers.
#Min number is 10.40 (the black line below the box).
#Median is 19.2 (the middle grean line in the box).
#First quarantile number is 15.42 which is below median.
#Third quarantile number is 22.8 which is greater than median.
#Max number is 33.9 (the black line above the box). 
#There is one outlier in the dataset(circle above the max line).
# Out:
# Text(0.5, 1.0, 'Box Plot of mpg column of mtcars Dataset')

# %%
#Question 4: Plot boxplots for all numerical columns in the dataset and provide your 
#comments on what you observe.
mtcars.boxplot(column="cyl",
 return_type='axes',
 figsize=(8,8)
)
plt.title('Box Plot of cyl column of mtcars Dataset')

#Comments on Box-plot
#A boxplot describes summary of five numbers of a dataset.
#These are minimum, first quartile, median, third quartile, and maximum numbers.
#Min number is 4 (the black line below the box).
#Median is 6 (the middle grean line in the box).
#First quarantile number is 4 which is equal to median.
#Third quarantile number is 8 which is greater than median.
#Max number is 8 (the black line above the box). 
#There is no outliers in the dataset.
# Out:
# Text(0.5, 1.0, 'Box Plot of cyl column of mtcars Dataset')

# %%
#Question 4: Plot boxplots for all numerical columns in the dataset and provide your 
#comments on what you observe.
mtcars.boxplot(column="disp",
 return_type='axes',
 figsize=(8,8)
)
plt.title('Box Plot of disp column of mtcars Dataset')
#Comments on Box-plot
#A boxplot describes summary of five numbers of a dataset.
#These are minimum, first quartile, median, third quartile, and maximum numbers.
#Min number is 71.1 (the black line below the box).
#Median is 196.3 (the middle grean line in the box).
#First quarantile number is 120.82 which is below median.
#Third quarantile number is 326 which is greater than median.
#Max number is 472 (the black line above the box). 
#There is no outliers in the dataset.
# Out:
# Text(0.5, 1.0, 'Box Plot of disp column of mtcars Dataset')

# %%
#Question 4: Plot boxplots for all numerical columns in the dataset and provide your 
#comments on what you observe.
mtcars.boxplot(column="hp",
 return_type='axes',
 figsize=(8,8)
)
plt.title('Box Plot of hp column of mtcars Dataset')
#Comments on Box-plot
#A boxplot describes summary of five numbers of a dataset.
#These are minimum, first quartile, median, third quartile, and maximum numbers.
#Min number is 52 (the black line below the box).
#Median is 123 (the middle grean line in the box).
#First quarantile number is 96.5 which is below median.
#Third quarantile number is 180 which is greater than median.
#Max number is 335 (the black line above the box). 
#There is one outlier in the dataset(circle above the max line).
# Out:
# Text(0.5, 1.0, 'Box Plot of hp column of mtcars Dataset')

# %%
#Question 4: Plot boxplots for all numerical columns in the dataset and provide your 
#comments on what you observe.
mtcars.boxplot(column="drat",
 return_type='axes',
 figsize=(8,8)
)
plt.title('Box Plot of drat column of mtcars Dataset')
#Comments on Box-plot
#A boxplot describes summary of five numbers of a dataset.
#These are minimum, first quartile, median, third quartile, and maximum numbers.
#Min number is 2.76 (the black line below the box).
#Median is 3.695 (the middle grean line in the box).
#First quarantile number is 3.08 which is below median.
#Third quarantile number is 3.92 which is greater than median.
#Max number is 4.93 (the black line above the box). 
#There is no outliers.
# Out:
# Text(0.5, 1.0, 'Box Plot of drat column of mtcars Dataset')

# %%
#Question 4: Plot boxplots for all numerical columns in the dataset and provide your 
#comments on what you observe.
mtcars.boxplot(column="wt",
 return_type='axes',
 figsize=(8,8)
)
plt.title('Box Plot of wt column of mtcars Dataset')
#Comments on Box-plot
#A boxplot describes summary of five numbers of a dataset.
#These are minimum, first quartile, median, third quartile, and maximum numbers.
#Min number is 1.51 (the black line below the box).
#Median is 3.325 (the middle grean line in the box).
#First quarantile number is 2.58 which is below median.
#Third quarantile number is 3.61 which is greater than median.
#Max number is 5.42 (the black line above the box). 
#There are three outliers in the dataset(circle above the max line).
# Out:
# Text(0.5, 1.0, 'Box Plot of wt column of mtcars Dataset')

# %%
#Question 4: Plot boxplots for all numerical columns in the dataset and provide your 
#comments on what you observe.
mtcars.boxplot(column="qsec",
 return_type='axes',
 figsize=(8,8)
)
plt.title('Box Plot of qsec column of mtcars Dataset')
#Comments on Box-plot
#A boxplot describes summary of five numbers of a dataset.
#These are minimum, first quartile, median, third quartile, and maximum numbers.
#Min number is 14.5 (the black line below the box).
#Median is 17.7 (the middle grean line in the box).
#First quarantile number is 16.89 which is below median.
#Third quarantile number is 18.9 which is greater than median.
#Max number is 22.9 (the black line above the box). 
#There is one outlier in the dataset(circle above the max line).
# Out:
# Text(0.5, 1.0, 'Box Plot of qsec column of mtcars Dataset')

# %%
#Question 4: Plot boxplots for all numerical columns in the dataset and provide your 
#comments on what you observe.
mtcars.boxplot(column="vs",
 return_type='axes',
 figsize=(8,8)
)
plt.title('Box Plot of vs column of mtcars Dataset')
#Comments on Box-plot
#A boxplot describes summary of five numbers of a dataset.
#These are minimum, first quartile, median, third quartile, and maximum numbers.
#Min number is 0.
#Median is 0 (grean line in the box).
#First quarantile number is 0.
#Third quarantile number is 1 which is greater than median.
#Max number is 1(the black line above the box).
# Out:
# Text(0.5, 1.0, 'Box Plot of vs column of mtcars Dataset')

# %%
#Question 4: Plot boxplots for all numerical columns in the dataset and provide your 
#comments on what you observe.
mtcars.boxplot(column="am",
 return_type='axes',
 figsize=(8,8)
)
plt.title('Box Plot of am column of mtcars Dataset')
#Comments on Box-plot
#A boxplot describes summary of five numbers of a dataset.
#These are minimum, first quartile, median, third quartile, and maximum numbers.
#Min number is 0.
#Median is 0 (grean line in the box).
#First quarantile number is 0.
#Third quarantile number is 1 which is greater than median.
#Max number is 1(the black line above the box).
# Out:
# Text(0.5, 1.0, 'Box Plot of am column of mtcars Dataset')

# %%
#Question 4: Plot boxplots for all numerical columns in the dataset and provide your 
#comments on what you observe.
mtcars.boxplot(column="gear",
 return_type='axes',
 figsize=(8,8)
)
plt.title('Box Plot of gear column of mtcars Dataset')
#Comments on Box-plot
#A boxplot describes summary of five numbers of a dataset.
#These are minimum, first quartile, median, third quartile, and maximum numbers.
#Min number is 3 (the black line below the box).
#Median is 4 (grean up in the box).
#First quarantile number is 3 which is below median.
#Third quarantile number is 4 which is greater than median.
#Max number is 5(the black line above the box). 
#No outliers
# Out:
# Text(0.5, 1.0, 'Box Plot of gear column of mtcars Dataset')

# %%
#Question 4: Plot boxplots for all numerical columns in the dataset and provide your 
#comments on what you observe.
mtcars.boxplot(column="carb",
 return_type='axes',
 figsize=(8,8)
)
plt.title('Box Plot of carb column of mtcars Dataset')
#Comments on Box-plot
#A boxplot describes summary of five numbers of a dataset.
#These are minimum, first quartile, median, third quartile, and maximum numbers.
#Min number is 1(the black line below the box).
#Median is 2(grean line below in the box).
#First quarantile number is 2 which is below median.
#Third quarantile number is 4 which is greater than median.
#Max number is 8(the black line above the box). 
#There is one outlier in the dataset(circle above the max line).
# Out:
# Text(0.5, 1.0, 'Box Plot of carb column of mtcars Dataset')
